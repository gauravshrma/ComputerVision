# %% [markdown]
# # Action Recognition @ UCF101
# **Due date: 11:59 pm on Nov. 19, 2019 (Tuesday)**
#
# ## Description
# ---
# In this homework, you will be doing action recognition using Recurrent Neural Network (RNN), (Long-Short Term Memory) LSTM in particular. You will be given a dataset called UCF101, which consists of 101 different actions/classes and for each action, there will be 145 samples. We tagged each sample into either training or testing. Each sample is supposed to be a short video, but we sampled 25 frames from each videos to reduce the amount of data. Consequently, a training sample is an image tuple that forms a 3D volume with one dimension encoding *temporal correlation* between frames and a label indicating what action it is.
#
# To tackle this problem, we aim to build a neural network that can not only capture spatial information of each frame but also temporal information between frames. Fortunately, you don't have to do this on your own. RNN — a type of neural network designed to deal with time-series data — is right here for you to use. In particular, you will be using LSTM for this task.
#
# Instead of training an end-to-end neural network from scratch whose computation is prohibitively expensive, we divide this into two steps: feature extraction and modelling. Below are the things you need to implement for this homework:
# - **{35 pts} Feature extraction**. Use any of the [pre-trained models](https://pytorch.org/docs/stable/torchvision/models.html) to extract features from each frame. Specifically, we recommend not to use the activations of the last layer as the features tend to be task specific towards the end of the network.
#     **hints**:
#     - A good starting point would be to use a pre-trained VGG16 network, we suggest first fully connected layer `torchvision.models.vgg16` (4096 dim) as features of each video frame. This will result into a 4096x25 matrix for each video.
#     - Normalize your images using `torchvision.transforms`
#     ```
#     normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#     prep = transforms.Compose([ transforms.ToTensor(), normalize ])
#     prep(img)
#     The mean and std. mentioned above is specific to Imagenet data
#
#     ```
#     More details of image preprocessing in PyTorch can be found at http://pytorch.org/tutorials/beginner/data_loading_tutorial.html
#
# - **{35 pts} Modelling**. With the extracted features, build an LSTM network which takes a **dx25** sample as input (where **d** is the dimension of the extracted feature for each frame), and outputs the action label of that sample.
# - **{20 pts} Evaluation**. After training your network, you need to evaluate your model with the testing data by computing the prediction accuracy **(5 points)**. The baseline test accuracy for this data is 75%, and **10 points** out of 20 is for achieving test accuracy greater than the baseline. Moreover, you need to compare **(5 points)** the result of your network with that of support vector machine (SVM) (stacking the **dx25** feature matrix to a long vector and train a SVM).
# - **{10 pts} Report**. Details regarding the report can be found in the submission section below.
#
# Notice that the size of the raw images is 256x340, whereas your pre-trained model might take **nxn** images as inputs. To solve this problem, instead of resizing the images which unfavorably changes the spatial ratio, we take a better solution: Cropping five **nxn** images, one at the image center and four at the corners and compute the **d**-dim features for each of them, and average these five **d**-dim feature to get a final feature representation for the raw image.
# For example, VGG takes 224x224 images as inputs, so we take the five 224x224 croppings of the image, compute 4096-dim VGG features for each of them, and then take the mean of these five 4096-dim vectors to be the representation of the image.
#
# In order to save you computational time, you need to do the classification task only for **the first 25** classes of the whole dataset. The same applies to those who have access to GPUs. **Bonus 10 points for running and reporting on the entire 101 classes.**
#
#
# ## Dataset
# Download **dataset** at [UCF101](http://vision.cs.stonybrook.edu/~yangwang/public/UCF101_images.tar)(Image data for each video) and the **annos folder** which has the video labels and the label to class name mapping is included in the assignment folder uploaded.
#
#
# UCF101 dataset contains 101 actions and 13,320 videos in total.
#
# + `annos/actions.txt`
#   + lists all the actions (`ApplyEyeMakeup`, .., `YoYo`)
#
# + `annots/videos_labels_subsets.txt`
#   + lists all the videos (`v_000001`, .., `v_013320`)
#   + labels (`1`, .., `101`)
#   + subsets (`1` for train, `2` for test)
#
# + `images/`
#   + each folder represents a video
#   + the video/folder name to class mapping can be found using `annots/videos_labels_subsets.txt`, for e.g. `v_000001` belongs to class 1 i.e. `ApplyEyeMakeup`
#   + each video folder contains 25 frames
#
#
#
# ## Some Tutorials
# - Good materials for understanding RNN and LSTM
#     - http://blog.echen.me
#     - http://karpathy.github.io/2015/05/21/rnn-effectiveness/
#     - http://colah.github.io/posts/2015-08-Understanding-LSTMs/
# - Implementing RNN and LSTM with PyTorch
#     - [LSTM with PyTorch](http://pytorch.org/tutorials/beginner/nlp/sequence_models_tutorial.html#sphx-glr-beginner-nlp-sequence-models-tutorial-py)
#     - [RNN with PyTorch](http://pytorch.org/tutorials/intermediate/char_rnn_classification_tutorial.html)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd '/content/drive/My Drive/Sharma_Gaurav_112680958_hw5/'
# Out:
# /content/drive/My Drive/Sharma_Gaurav_112680958_hw5

# %%
#!wget http://vision.cs.stonybrook.edu/~yangwang/public/UCF101_images.tar

# %%
#!tar -xvf 'UCF101_images.tar'
# Out:
# images/
# images/v_000001/
# images/v_000001/i_0001.jpg
# images/v_000001/i_0002.jpg
# images/v_000001/i_0003.jpg
# images/v_000001/i_0004.jpg
# images/v_000001/i_0005.jpg
# images/v_000001/i_0006.jpg
# images/v_000001/i_0007.jpg
# images/v_000001/i_0008.jpg
# images/v_000001/i_0009.jpg
# images/v_000001/i_0010.jpg
# images/v_000001/i_0011.jpg
# images/v_000001/i_0012.jpg
# images/v_000001/i_0013.jpg
# images/v_000001/i_0014.jpg
# images/v_000001/i_0015.jpg
# images/v_000001/i_0016.jpg
# images/v_000001/i_0017.jpg
# images/v_000001/i_0018.jpg
# images/v_000001/i_0019.jpg
# images/v_000001/i_0020.jpg
# images/v_000001/i_0021.jpg
# images/v_000001/i_0022.jpg
# images/v_000001/i_0023.jpg
# images/v_000001/i_0024.jpg
# images/v_000001/i_0025.jpg
# images/v_000002/
# images/v_000002/i_0001.jpg
# images/v_000002/i_0002.jpg
# images/v_000002/i_0003.jpg
# images/v_000002/i_0004.jpg
# images/v_000002/i_0005.jpg
# images/v_000002/i_0006.jpg
# images/v_000002/i_0007.jpg
# images/v_000002/i_0008.jpg
# images/v_000002/i_0009.jpg
# images/v_000002/i_0010.jpg
# images/v_000002/i_0011.jpg
# images/v_000002/i_0012.jpg
# images/v_000002/i_0013.jpg
# images/v_000002/i_0014.jpg
# images/v_000002/i_0015.jpg
# images/v_000002/i_0016.jpg
# images/v_000002/i_0017.jpg
# images/v_000002/i_0018.jpg
# images/v_000002/i_0019.jpg
# images/v_000002/i_0020.jpg
# images/v_000002/i_0021.jpg
# images/v_000002/i_0022.jpg
# images/v_000002/i_0023.jpg
# images/v_000002/i_0024.jpg
# images/v_000002/i_0025.jpg
# images/v_000003/
# images/v_000003/i_0001.jpg
# images/v_000003/i_0002.jpg
# images/v_000003/i_0003.jpg
# images/v_000003/i_0004.jpg
# images/v_000003/i_0005.jpg
# images/v_000003/i_0006.jpg
# images/v_000003/i_0007.jpg
# images/v_000003/i_0008.jpg
# images/v_000003/i_0009.jpg
# images/v_000003/i_0010.jpg
# images/v_000003/i_0011.jpg
# images/v_000003/i_0012.jpg
# images/v_000003/i_0013.jpg
# images/v_000003/i_0014.jpg
# images/v_000003/i_0015.jpg
# images/v_000003/i_0016.jpg
# images/v_000003/i_0017.jpg
# images/v_000003/i_0018.jpg
# images/v_000003/i_0019.jpg
# images/v_000003/i_0020.jpg
# images/v_000003/i_0021.jpg
# images/v_000003/i_0022.jpg
# images/v_000003/i_0023.jpg
# images/v_000003/i_0024.jpg
# images/v_000003/i_0025.jpg
# images/v_000004/
# images/v_000004/i_0001.jpg
# images/v_000004/i_0002.jpg
# images/v_000004/i_0003.jpg
# images/v_000004/i_0004.jpg
# images/v_000004/i_0005.jpg
# images/v_000004/i_0006.jpg
# images/v_000004/i_0007.jpg
# images/v_000004/i_0008.jpg
# images/v_000004/i_0009.jpg
# images/v_000004/i_0010.jpg
# images/v_000004/i_0011.jpg
# images/v_000004/i_0012.jpg
# images/v_000004/i_0013.jpg
# images/v_000004/i_0014.jpg
# images/v_000004/i_0015.jpg
# images/v_000004/i_0016.jpg
# images/v_000004/i_0017.jpg
# images/v_000004/i_0018.jpg
# images/v_000004/i_0019.jpg
# images/v_000004/i_0020.jpg
# images/v_000004/i_0021.jpg
# images/v_000004/i_0022.jpg
# images/v_000004/i_0023.jpg
# images/v_000004/i_0024.jpg
# images/v_000004/i_0025.jpg
# images/v_000005/
# images/v_000005/i_0001.jpg
# images/v_000005/i_0002.jpg
# images/v_000005/i_0003.jpg
# images/v_000005/i_0004.jpg
# images/v_000005/i_0005.jpg
# images/v_000005/i_0006.jpg
# images/v_000005/i_0007.jpg
# images/v_000005/i_0008.jpg
# images/v_000005/i_0009.jpg
# images/v_000005/i_0010.jpg
# images/v_000005/i_0011.jpg
# images/v_000005/i_0012.jpg
# images/v_000005/i_0013.jpg
# images/v_000005/i_0014.jpg
# images/v_000005/i_0015.jpg
# images/v_000005/i_0016.jpg
# images/v_000005/i_0017.jpg
# images/v_000005/i_0018.jpg
# images/v_000005/i_0019.jpg
# images/v_000005/i_0020.jpg
# images/v_000005/i_0021.jpg
# images/v_000005/i_0022.jpg
# images/v_000005/i_0023.jpg
# images/v_000005/i_0024.jpg
# images/v_000005/i_0025.jpg
# images/v_000006/
# images/v_000006/i_0001.jpg
# images/v_000006/i_0002.jpg
# images/v_000006/i_0003.jpg
# images/v_000006/i_0004.jpg
# images/v_000006/i_0005.jpg
# images/v_000006/i_0006.jpg
# images/v_000006/i_0007.jpg
# images/v_000006/i_0008.jpg
# images/v_000006/i_0009.jpg
# images/v_000006/i_0010.jpg
# images/v_000006/i_0011.jpg
# images/v_000006/i_0012.jpg
# images/v_000006/i_0013.jpg
# images/v_000006/i_0014.jpg
# images/v_000006/i_0015.jpg
# images/v_000006/i_0016.jpg
# images/v_000006/i_0017.jpg
# images/v_000006/i_0018.jpg
# images/v_000006/i_0019.jpg
# images/v_000006/i_0020.jpg
# images/v_000006/i_0021.jpg
# images/v_000006/i_0022.jpg
# images/v_000006/i_0023.jpg
# images/v_000006/i_0024.jpg
# images/v_000006/i_0025.jpg
# images/v_000007/
# images/v_000007/i_0001.jpg
# images/v_000007/i_0002.jpg
# images/v_000007/i_0003.jpg
# images/v_000007/i_0004.jpg
# images/v_000007/i_0005.jpg
# images/v_000007/i_0006.jpg
# images/v_000007/i_0007.jpg
# images/v_000007/i_0008.jpg
# images/v_000007/i_0009.jpg
# images/v_000007/i_0010.jpg
# images/v_000007/i_0011.jpg
# images/v_000007/i_0012.jpg
# images/v_000007/i_0013.jpg
# images/v_000007/i_0014.jpg
# images/v_000007/i_0015.jpg
# images/v_000007/i_0016.jpg
# images/v_000007/i_0017.jpg
# images/v_000007/i_0018.jpg
# images/v_000007/i_0019.jpg
# images/v_000007/i_0020.jpg
# images/v_000007/i_0021.jpg
# images/v_000007/i_0022.jpg
# images/v_000007/i_0023.jpg
# images/v_000007/i_0024.jpg
# images/v_000007/i_0025.jpg
# images/v_000008/
# images/v_000008/i_0001.jpg
# images/v_000008/i_0002.jpg
# images/v_000008/i_0003.jpg
# images/v_000008/i_0004.jpg
# images/v_000008/i_0005.jpg
# images/v_000008/i_0006.jpg
# images/v_000008/i_0007.jpg
# images/v_000008/i_0008.jpg
# images/v_000008/i_0009.jpg
# images/v_000008/i_0010.jpg
# images/v_000008/i_0011.jpg
# images/v_000008/i_0012.jpg
# images/v_000008/i_0013.jpg
# images/v_000008/i_0014.jpg
# images/v_000008/i_0015.jpg
# images/v_000008/i_0016.jpg
# images/v_000008/i_0017.jpg
# images/v_000008/i_0018.jpg
# images/v_000008/i_0019.jpg
# images/v_000008/i_0020.jpg
# images/v_000008/i_0021.jpg
# images/v_000008/i_0022.jpg
# images/v_000008/i_0023.jpg
# images/v_000008/i_0024.jpg
# images/v_000008/i_0025.jpg
# images/v_000009/
# images/v_000009/i_0001.jpg
# images/v_000009/i_0002.jpg
# images/v_000009/i_0003.jpg
# images/v_000009/i_0004.jpg
# images/v_000009/i_0005.jpg
# images/v_000009/i_0006.jpg
# images/v_000009/i_0007.jpg
# images/v_000009/i_0008.jpg
# images/v_000009/i_0009.jpg
# images/v_000009/i_0010.jpg
# images/v_000009/i_0011.jpg
# images/v_000009/i_0012.jpg
# images/v_000009/i_0013.jpg
# images/v_000009/i_0014.jpg
# images/v_000009/i_0015.jpg
# images/v_000009/i_0016.jpg
# images/v_000009/i_0017.jpg
# images/v_000009/i_0018.jpg
# images/v_000009/i_0019.jpg
# images/v_000009/i_0020.jpg
# images/v_000009/i_0021.jpg
# images/v_000009/i_0022.jpg
# images/v_000009/i_0023.jpg
# images/v_000009/i_0024.jpg
# images/v_000009/i_0025.jpg
# images/v_000010/
# images/v_000010/i_0001.jpg
# images/v_000010/i_0002.jpg
# images/v_000010/i_0003.jpg
# images/v_000010/i_0004.jpg
# images/v_000010/i_0005.jpg
# images/v_000010/i_0006.jpg
# images/v_000010/i_0007.jpg
# images/v_000010/i_0008.jpg
# images/v_000010/i_0009.jpg
# images/v_000010/i_0010.jpg
# images/v_000010/i_0011.jpg
# images/v_000010/i_0012.jpg
# images/v_000010/i_0013.jpg
# images/v_000010/i_0014.jpg
# images/v_000010/i_0015.jpg
# images/v_000010/i_0016.jpg
# images/v_000010/i_0017.jpg
# images/v_000010/i_0018.jpg
# images/v_000010/i_0019.jpg
# images/v_000010/i_0020.jpg
# images/v_000010/i_0021.jpg
# images/v_000010/i_0022.jpg
# images/v_000010/i_0023.jpg
# images/v_000010/i_0024.jpg
# images/v_000010/i_0025.jpg
# images/v_000011/
# images/v_000011/i_0001.jpg
# images/v_000011/i_0002.jpg
# images/v_000011/i_0003.jpg
# images/v_000011/i_0004.jpg
# images/v_000011/i_0005.jpg
# images/v_000011/i_0006.jpg
# images/v_000011/i_0007.jpg
# images/v_000011/i_0008.jpg
# images/v_000011/i_0009.jpg
# images/v_000011/i_0010.jpg
# images/v_000011/i_0011.jpg
# images/v_000011/i_0012.jpg
# images/v_000011/i_0013.jpg
# images/v_000011/i_0014.jpg
# images/v_000011/i_0015.jpg
# images/v_000011/i_0016.jpg
# images/v_000011/i_0017.jpg
# images/v_000011/i_0018.jpg
# images/v_000011/i_0019.jpg
# images/v_000011/i_0020.jpg
# images/v_000011/i_0021.jpg
# images/v_000011/i_0022.jpg
# images/v_000011/i_0023.jpg
# images/v_000011/i_0024.jpg
# images/v_000011/i_0025.jpg
# images/v_000012/
# images/v_000012/i_0001.jpg
# images/v_000012/i_0002.jpg
# images/v_000012/i_0003.jpg
# images/v_000012/i_0004.jpg
# images/v_000012/i_0005.jpg
# images/v_000012/i_0006.jpg
# images/v_000012/i_0007.jpg
# images/v_000012/i_0008.jpg
# images/v_000012/i_0009.jpg
# images/v_000012/i_0010.jpg
# images/v_000012/i_0011.jpg
# images/v_000012/i_0012.jpg
# images/v_000012/i_0013.jpg
# images/v_000012/i_0014.jpg
# images/v_000012/i_0015.jpg
# images/v_000012/i_0016.jpg
# images/v_000012/i_0017.jpg
# images/v_000012/i_0018.jpg
# images/v_000012/i_0019.jpg
# images/v_000012/i_0020.jpg
# images/v_000012/i_0021.jpg
# images/v_000012/i_0022.jpg
# images/v_000012/i_0023.jpg
# images/v_000012/i_0024.jpg
# images/v_000012/i_0025.jpg
# images/v_000013/
# images/v_000013/i_0001.jpg
# images/v_000013/i_0002.jpg
# images/v_000013/i_0003.jpg
# images/v_000013/i_0004.jpg
# images/v_000013/i_0005.jpg
# images/v_000013/i_0006.jpg
# images/v_000013/i_0007.jpg
# images/v_000013/i_0008.jpg
# images/v_000013/i_0009.jpg
# images/v_000013/i_0010.jpg
# images/v_000013/i_0011.jpg
# images/v_000013/i_0012.jpg
# images/v_000013/i_0013.jpg
# images/v_000013/i_0014.jpg
# images/v_000013/i_0015.jpg
# images/v_000013/i_0016.jpg
# images/v_000013/i_0017.jpg
# images/v_000013/i_0018.jpg
# images/v_000013/i_0019.jpg
# images/v_000013/i_0020.jpg
# images/v_000013/i_0021.jpg
# images/v_000013/i_0022.jpg
# images/v_000013/i_0023.jpg
# images/v_000013/i_0024.jpg
# images/v_000013/i_0025.jpg
# images/v_000014/
# images/v_000014/i_0001.jpg
# images/v_000014/i_0002.jpg
# images/v_000014/i_0003.jpg
# images/v_000014/i_0004.jpg
# images/v_000014/i_0005.jpg
# images/v_000014/i_0006.jpg
# images/v_000014/i_0007.jpg
# images/v_000014/i_0008.jpg
# images/v_000014/i_0009.jpg
# images/v_000014/i_0010.jpg
# images/v_000014/i_0011.jpg
# images/v_000014/i_0012.jpg
# images/v_000014/i_0013.jpg
# images/v_000014/i_0014.jpg
# images/v_000014/i_0015.jpg
# images/v_000014/i_0016.jpg
# images/v_000014/i_0017.jpg
# images/v_000014/i_0018.jpg
# images/v_000014/i_0019.jpg
# images/v_000014/i_0020.jpg
# images/v_000014/i_0021.jpg
# images/v_000014/i_0022.jpg
# images/v_000014/i_0023.jpg
# images/v_000014/i_0024.jpg
# images/v_000014/i_0025.jpg
# images/v_000015/
# images/v_000015/i_0001.jpg
# images/v_000015/i_0002.jpg
# images/v_000015/i_0003.jpg
# images/v_000015/i_0004.jpg
# images/v_000015/i_0005.jpg
# images/v_000015/i_0006.jpg
# images/v_000015/i_0007.jpg
# images/v_000015/i_0008.jpg
# images/v_000015/i_0009.jpg
# images/v_000015/i_0010.jpg
# images/v_000015/i_0011.jpg
# images/v_000015/i_0012.jpg
# images/v_000015/i_0013.jpg
# images/v_000015/i_0014.jpg
# images/v_000015/i_0015.jpg
# images/v_000015/i_0016.jpg
# images/v_000015/i_0017.jpg
# images/v_000015/i_0018.jpg
# images/v_000015/i_0019.jpg
# images/v_000015/i_0020.jpg
# images/v_000015/i_0021.jpg
# images/v_000015/i_0022.jpg
# images/v_000015/i_0023.jpg
# images/v_000015/i_0024.jpg
# images/v_000015/i_0025.jpg
# images/v_000016/
# images/v_000016/i_0001.jpg
# images/v_000016/i_0002.jpg
# images/v_000016/i_0003.jpg
# images/v_000016/i_0004.jpg
# images/v_000016/i_0005.jpg
# images/v_000016/i_0006.jpg
# images/v_000016/i_0007.jpg
# images/v_000016/i_0008.jpg
# images/v_000016/i_0009.jpg
# images/v_000016/i_0010.jpg
# images/v_000016/i_0011.jpg
# images/v_000016/i_0012.jpg
# images/v_000016/i_0013.jpg
# images/v_000016/i_0014.jpg
# images/v_000016/i_0015.jpg
# images/v_000016/i_0016.jpg
# images/v_000016/i_0017.jpg
# images/v_000016/i_0018.jpg
# images/v_000016/i_0019.jpg
# images/v_000016/i_0020.jpg
# images/v_000016/i_0021.jpg
# images/v_000016/i_0022.jpg
# images/v_000016/i_0023.jpg
# images/v_000016/i_0024.jpg
# images/v_000016/i_0025.jpg
# images/v_000017/
# images/v_000017/i_0001.jpg
# images/v_000017/i_0002.jpg
# images/v_000017/i_0003.jpg
# images/v_000017/i_0004.jpg
# images/v_000017/i_0005.jpg
# images/v_000017/i_0006.jpg
# images/v_000017/i_0007.jpg
# images/v_000017/i_0008.jpg
# images/v_000017/i_0009.jpg
# images/v_000017/i_0010.jpg
# images/v_000017/i_0011.jpg
# images/v_000017/i_0012.jpg
# images/v_000017/i_0013.jpg
# images/v_000017/i_0014.jpg
# images/v_000017/i_0015.jpg
# images/v_000017/i_0016.jpg
# images/v_000017/i_0017.jpg
# images/v_000017/i_0018.jpg
# images/v_000017/i_0019.jpg
# images/v_000017/i_0020.jpg
# images/v_000017/i_0021.jpg
# images/v_000017/i_0022.jpg
# images/v_000017/i_0023.jpg
# images/v_000017/i_0024.jpg
# images/v_000017/i_0025.jpg
# images/v_000018/
# images/v_000018/i_0001.jpg
# images/v_000018/i_0002.jpg
# images/v_000018/i_0003.jpg
# images/v_000018/i_0004.jpg
# images/v_000018/i_0005.jpg
# images/v_000018/i_0006.jpg
# images/v_000018/i_0007.jpg
# images/v_000018/i_0008.jpg
# images/v_000018/i_0009.jpg
# images/v_000018/i_0010.jpg
# images/v_000018/i_0011.jpg
# images/v_000018/i_0012.jpg
# images/v_000018/i_0013.jpg
# images/v_000018/i_0014.jpg
# images/v_000018/i_0015.jpg
# images/v_000018/i_0016.jpg
# images/v_000018/i_0017.jpg
# images/v_000018/i_0018.jpg
# images/v_000018/i_0019.jpg
# images/v_000018/i_0020.jpg
# images/v_000018/i_0021.jpg
# images/v_000018/i_0022.jpg
# images/v_000018/i_0023.jpg
# images/v_000018/i_0024.jpg
# images/v_000018/i_0025.jpg
# images/v_000019/
# images/v_000019/i_0001.jpg
# images/v_000019/i_0002.jpg
# images/v_000019/i_0003.jpg
# images/v_000019/i_0004.jpg
# images/v_000019/i_0005.jpg
# images/v_000019/i_0006.jpg
# images/v_000019/i_0007.jpg
# images/v_000019/i_0008.jpg
# images/v_000019/i_0009.jpg
# images/v_000019/i_0010.jpg
# images/v_000019/i_0011.jpg
# images/v_000019/i_0012.jpg
# images/v_000019/i_0013.jpg
# images/v_000019/i_0014.jpg
# images/v_000019/i_0015.jpg
# images/v_000019/i_0016.jpg
# images/v_000019/i_0017.jpg
# images/v_000019/i_0018.jpg
# images/v_000019/i_0019.jpg
# images/v_000019/i_0020.jpg
# images/v_000019/i_0021.jpg
# images/v_000019/i_0022.jpg
# images/v_000019/i_0023.jpg
# images/v_000019/i_0024.jpg
# images/v_000019/i_0025.jpg
# images/v_000020/
# images/v_000020/i_0001.jpg
# images/v_000020/i_0002.jpg
# images/v_000020/i_0003.jpg
# images/v_000020/i_0004.jpg
# images/v_000020/i_0005.jpg
# images/v_000020/i_0006.jpg
# images/v_000020/i_0007.jpg
# images/v_000020/i_0008.jpg
# images/v_000020/i_0009.jpg
# images/v_000020/i_0010.jpg
# images/v_000020/i_0011.jpg
# images/v_000020/i_0012.jpg
# images/v_000020/i_0013.jpg
# images/v_000020/i_0014.jpg
# images/v_000020/i_0015.jpg
# images/v_000020/i_0016.jpg
# images/v_000020/i_0017.jpg
# images/v_000020/i_0018.jpg
# images/v_000020/i_0019.jpg
# images/v_000020/i_0020.jpg
# images/v_000020/i_0021.jpg
# images/v_000020/i_0022.jpg
# images/v_000020/i_0023.jpg
# images/v_000020/i_0024.jpg
# images/v_000020/i_0025.jpg
# images/v_000021/
# images/v_000021/i_0001.jpg
# images/v_000021/i_0002.jpg
# images/v_000021/i_0003.jpg
# images/v_000021/i_0004.jpg
# images/v_000021/i_0005.jpg
# images/v_000021/i_0006.jpg
# images/v_000021/i_0007.jpg
# images/v_000021/i_0008.jpg
# images/v_000021/i_0009.jpg
# images/v_000021/i_0010.jpg
# images/v_000021/i_0011.jpg
# images/v_000021/i_0012.jpg
# images/v_000021/i_0013.jpg
# images/v_000021/i_0014.jpg
# images/v_000021/i_0015.jpg
# images/v_000021/i_0016.jpg
# images/v_000021/i_0017.jpg
# images/v_000021/i_0018.jpg
# images/v_000021/i_0019.jpg
# images/v_000021/i_0020.jpg
# images/v_000021/i_0021.jpg
# images/v_000021/i_0022.jpg
# images/v_000021/i_0023.jpg
# images/v_000021/i_0024.jpg
# images/v_000021/i_0025.jpg
# images/v_000022/
# images/v_000022/i_0001.jpg
# images/v_000022/i_0002.jpg
# images/v_000022/i_0003.jpg
# images/v_000022/i_0004.jpg
# images/v_000022/i_0005.jpg
# images/v_000022/i_0006.jpg
# images/v_000022/i_0007.jpg
# images/v_000022/i_0008.jpg
# images/v_000022/i_0009.jpg
# images/v_000022/i_0010.jpg
# images/v_000022/i_0011.jpg
# images/v_000022/i_0012.jpg
# images/v_000022/i_0013.jpg
# images/v_000022/i_0014.jpg
# images/v_000022/i_0015.jpg
# images/v_000022/i_0016.jpg
# images/v_000022/i_0017.jpg
# images/v_000022/i_0018.jpg
# images/v_000022/i_0019.jpg
# images/v_000022/i_0020.jpg
# images/v_000022/i_0021.jpg
# images/v_000022/i_0022.jpg
# images/v_000022/i_0023.jpg
# images/v_000022/i_0024.jpg
# images/v_000022/i_0025.jpg
# images/v_000023/
# images/v_000023/i_0001.jpg
# images/v_000023/i_0002.jpg
# images/v_000023/i_0003.jpg
# images/v_000023/i_0004.jpg
# images/v_000023/i_0005.jpg
# images/v_000023/i_0006.jpg
# images/v_000023/i_0007.jpg
# images/v_000023/i_0008.jpg
# images/v_000023/i_0009.jpg
# images/v_000023/i_0010.jpg
# images/v_000023/i_0011.jpg
# images/v_000023/i_0012.jpg
# images/v_000023/i_0013.jpg
# images/v_000023/i_0014.jpg
# images/v_000023/i_0015.jpg
# images/v_000023/i_0016.jpg
# images/v_000023/i_0017.jpg
# images/v_000023/i_0018.jpg
# images/v_000023/i_0019.jpg
# images/v_000023/i_0020.jpg
# images/v_000023/i_0021.jpg
# images/v_000023/i_0022.jpg
# images/v_000023/i_0023.jpg
# images/v_000023/i_0024.jpg
# images/v_000023/i_0025.jpg
# images/v_000024/
# images/v_000024/i_0001.jpg
# images/v_000024/i_0002.jpg
# images/v_000024/i_0003.jpg
# images/v_000024/i_0004.jpg
# images/v_000024/i_0005.jpg
# images/v_000024/i_0006.jpg
# images/v_000024/i_0007.jpg
# images/v_000024/i_0008.jpg
# images/v_000024/i_0009.jpg
# images/v_000024/i_0010.jpg
# images/v_000024/i_0011.jpg
# images/v_000024/i_0012.jpg
# images/v_000024/i_0013.jpg
# images/v_000024/i_0014.jpg
# images/v_000024/i_0015.jpg
# images/v_000024/i_0016.jpg
# images/v_000024/i_0017.jpg
# images/v_000024/i_0018.jpg
# images/v_000024/i_0019.jpg
# images/v_000024/i_0020.jpg
# images/v_000024/i_0021.jpg
# images/v_000024/i_0022.jpg
# images/v_000024/i_0023.jpg
# images/v_000024/i_0024.jpg
# images/v_000024/i_0025.jpg
# images/v_000025/
# images/v_000025/i_0001.jpg
# images/v_000025/i_0002.jpg
# images/v_000025/i_0003.jpg
# images/v_000025/i_0004.jpg
# images/v_000025/i_0005.jpg
# images/v_000025/i_0006.jpg
# images/v_000025/i_0007.jpg
# images/v_000025/i_0008.jpg
# images/v_000025/i_0009.jpg
# images/v_000025/i_0010.jpg
# images/v_000025/i_0011.jpg
# images/v_000025/i_0012.jpg
# images/v_000025/i_0013.jpg
# images/v_000025/i_0014.jpg
# images/v_000025/i_0015.jpg
# images/v_000025/i_0016.jpg
# images/v_000025/i_0017.jpg
# images/v_000025/i_0018.jpg
# images/v_000025/i_0019.jpg
# images/v_000025/i_0020.jpg
# images/v_000025/i_0021.jpg
# images/v_000025/i_0022.jpg
# images/v_000025/i_0023.jpg
# images/v_000025/i_0024.jpg
# images/v_000025/i_0025.jpg
# images/v_000026/
# images/v_000026/i_0001.jpg
# images/v_000026/i_0002.jpg
# images/v_000026/i_0003.jpg
# images/v_000026/i_0004.jpg
# images/v_000026/i_0005.jpg
# images/v_000026/i_0006.jpg
# images/v_000026/i_0007.jpg
# images/v_000026/i_0008.jpg
# images/v_000026/i_0009.jpg
# images/v_000026/i_0010.jpg
# images/v_000026/i_0011.jpg
# images/v_000026/i_0012.jpg
# images/v_000026/i_0013.jpg
# images/v_000026/i_0014.jpg
# images/v_000026/i_0015.jpg
# images/v_000026/i_0016.jpg
# images/v_000026/i_0017.jpg
# images/v_000026/i_0018.jpg
# images/v_000026/i_0019.jpg
# images/v_000026/i_0020.jpg
# images/v_000026/i_0021.jpg
# images/v_000026/i_0022.jpg
# images/v_000026/i_0023.jpg
# images/v_000026/i_0024.jpg
# images/v_000026/i_0025.jpg
# images/v_000027/
# images/v_000027/i_0001.jpg
# images/v_000027/i_0002.jpg
# images/v_000027/i_0003.jpg
# images/v_000027/i_0004.jpg
# images/v_000027/i_0005.jpg
# images/v_000027/i_0006.jpg
# images/v_000027/i_0007.jpg
# images/v_000027/i_0008.jpg
# images/v_000027/i_0009.jpg
# images/v_000027/i_0010.jpg
# images/v_000027/i_0011.jpg
# images/v_000027/i_0012.jpg
# images/v_000027/i_0013.jpg
# images/v_000027/i_0014.jpg
# images/v_000027/i_0015.jpg
# images/v_000027/i_0016.jpg
# images/v_000027/i_0017.jpg
# images/v_000027/i_0018.jpg
# images/v_000027/i_0019.jpg
# images/v_000027/i_0020.jpg
# images/v_000027/i_0021.jpg
# images/v_000027/i_0022.jpg
# images/v_000027/i_0023.jpg
# images/v_000027/i_0024.jpg
# images/v_000027/i_0025.jpg
# images/v_000028/
# images/v_000028/i_0001.jpg
# images/v_000028/i_0002.jpg
# images/v_000028/i_0003.jpg
# images/v_000028/i_0004.jpg
# images/v_000028/i_0005.jpg
# images/v_000028/i_0006.jpg
# images/v_000028/i_0007.jpg
# images/v_000028/i_0008.jpg
# images/v_000028/i_0009.jpg
# images/v_000028/i_0010.jpg
# images/v_000028/i_0011.jpg
# images/v_000028/i_0012.jpg
# images/v_000028/i_0013.jpg
# images/v_000028/i_0014.jpg
# images/v_000028/i_0015.jpg
# images/v_000028/i_0016.jpg
# images/v_000028/i_0017.jpg
# images/v_000028/i_0018.jpg
# images/v_000028/i_0019.jpg
# images/v_000028/i_0020.jpg
# images/v_000028/i_0021.jpg
# images/v_000028/i_0022.jpg
# images/v_000028/i_0023.jpg
# images/v_000028/i_0024.jpg
# images/v_000028/i_0025.jpg
# images/v_000029/
# images/v_000029/i_0001.jpg
# images/v_000029/i_0002.jpg
# images/v_000029/i_0003.jpg
# images/v_000029/i_0004.jpg
# images/v_000029/i_0005.jpg
# images/v_000029/i_0006.jpg
# images/v_000029/i_0007.jpg
# images/v_000029/i_0008.jpg
# images/v_000029/i_0009.jpg
# images/v_000029/i_0010.jpg
# images/v_000029/i_0011.jpg
# images/v_000029/i_0012.jpg
# images/v_000029/i_0013.jpg
# images/v_000029/i_0014.jpg
# images/v_000029/i_0015.jpg
# images/v_000029/i_0016.jpg
# images/v_000029/i_0017.jpg
# images/v_000029/i_0018.jpg
# images/v_000029/i_0019.jpg
# images/v_000029/i_0020.jpg
# images/v_000029/i_0021.jpg
# images/v_000029/i_0022.jpg
# images/v_000029/i_0023.jpg
# images/v_000029/i_0024.jpg
# images/v_000029/i_0025.jpg
# images/v_000030/
# images/v_000030/i_0001.jpg
# images/v_000030/i_0002.jpg
# images/v_000030/i_0003.jpg
# images/v_000030/i_0004.jpg
# images/v_000030/i_0005.jpg
# images/v_000030/i_0006.jpg
# images/v_000030/i_0007.jpg
# images/v_000030/i_0008.jpg
# images/v_000030/i_0009.jpg
# images/v_000030/i_0010.jpg
# images/v_000030/i_0011.jpg
# images/v_000030/i_0012.jpg
# images/v_000030/i_0013.jpg
# images/v_000030/i_0014.jpg
# images/v_000030/i_0015.jpg
# images/v_000030/i_0016.jpg
# images/v_000030/i_0017.jpg
# images/v_000030/i_0018.jpg
# images/v_000030/i_0019.jpg
# images/v_000030/i_0020.jpg
# images/v_000030/i_0021.jpg
# images/v_000030/i_0022.jpg
# images/v_000030/i_0023.jpg
# images/v_000030/i_0024.jpg
# images/v_000030/i_0025.jpg
# images/v_000031/
# images/v_000031/i_0001.jpg
# images/v_000031/i_0002.jpg
# images/v_000031/i_0003.jpg
# images/v_000031/i_0004.jpg
# images/v_000031/i_0005.jpg
# images/v_000031/i_0006.jpg
# images/v_000031/i_0007.jpg
# images/v_000031/i_0008.jpg
# images/v_000031/i_0009.jpg
# images/v_000031/i_0010.jpg
# images/v_000031/i_0011.jpg
# images/v_000031/i_0012.jpg
# images/v_000031/i_0013.jpg
# images/v_000031/i_0014.jpg
# images/v_000031/i_0015.jpg
# images/v_000031/i_0016.jpg
# images/v_000031/i_0017.jpg
# images/v_000031/i_0018.jpg
# images/v_000031/i_0019.jpg
# images/v_000031/i_0020.jpg
# images/v_000031/i_0021.jpg
# images/v_000031/i_0022.jpg
# images/v_000031/i_0023.jpg
# images/v_000031/i_0024.jpg
# images/v_000031/i_0025.jpg
# images/v_000032/
# images/v_000032/i_0001.jpg
# images/v_000032/i_0002.jpg
# images/v_000032/i_0003.jpg
# images/v_000032/i_0004.jpg
# images/v_000032/i_0005.jpg
# images/v_000032/i_0006.jpg
# images/v_000032/i_0007.jpg
# images/v_000032/i_0008.jpg
# images/v_000032/i_0009.jpg
# images/v_000032/i_0010.jpg
# images/v_000032/i_0011.jpg
# images/v_000032/i_0012.jpg
# images/v_000032/i_0013.jpg
# images/v_000032/i_0014.jpg
# images/v_000032/i_0015.jpg
# images/v_000032/i_0016.jpg
# images/v_000032/i_0017.jpg
# images/v_000032/i_0018.jpg
# images/v_000032/i_0019.jpg
# images/v_000032/i_0020.jpg
# images/v_000032/i_0021.jpg
# images/v_000032/i_0022.jpg
# images/v_000032/i_0023.jpg
# images/v_000032/i_0024.jpg
# images/v_000032/i_0025.jpg
# images/v_000033/
# images/v_000033/i_0001.jpg
# images/v_000033/i_0002.jpg
# images/v_000033/i_0003.jpg
# images/v_000033/i_0004.jpg
# images/v_000033/i_0005.jpg
# images/v_000033/i_0006.jpg
# images/v_000033/i_0007.jpg
# images/v_000033/i_0008.jpg
# images/v_000033/i_0009.jpg
# images/v_000033/i_0010.jpg
# images/v_000033/i_0011.jpg
# images/v_000033/i_0012.jpg
# images/v_000033/i_0013.jpg
# images/v_000033/i_0014.jpg
# images/v_000033/i_0015.jpg
# images/v_000033/i_0016.jpg
# images/v_000033/i_0017.jpg
# images/v_000033/i_0018.jpg
# images/v_000033/i_0019.jpg
# images/v_000033/i_0020.jpg
# images/v_000033/i_0021.jpg
# images/v_000033/i_0022.jpg
# images/v_000033/i_0023.jpg
# images/v_000033/i_0024.jpg
# images/v_000033/i_0025.jpg
# images/v_000034/
# images/v_000034/i_0001.jpg
# images/v_000034/i_0002.jpg
# images/v_000034/i_0003.jpg
# images/v_000034/i_0004.jpg
# images/v_000034/i_0005.jpg
# images/v_000034/i_0006.jpg
# images/v_000034/i_0007.jpg
# images/v_000034/i_0008.jpg
# images/v_000034/i_0009.jpg
# images/v_000034/i_0010.jpg
# images/v_000034/i_0011.jpg
# images/v_000034/i_0012.jpg
# images/v_000034/i_0013.jpg
# images/v_000034/i_0014.jpg
# images/v_000034/i_0015.jpg
# images/v_000034/i_0016.jpg
# images/v_000034/i_0017.jpg
# images/v_000034/i_0018.jpg
# images/v_000034/i_0019.jpg
# images/v_000034/i_0020.jpg
# images/v_000034/i_0021.jpg
# images/v_000034/i_0022.jpg
# images/v_000034/i_0023.jpg
# images/v_000034/i_0024.jpg
# images/v_000034/i_0025.jpg
# images/v_000035/
# images/v_000035/i_0001.jpg
# images/v_000035/i_0002.jpg
# images/v_000035/i_0003.jpg
# images/v_000035/i_0004.jpg
# images/v_000035/i_0005.jpg
# images/v_000035/i_0006.jpg
# images/v_000035/i_0007.jpg
# images/v_000035/i_0008.jpg
# images/v_000035/i_0009.jpg
# images/v_000035/i_0010.jpg
# images/v_000035/i_0011.jpg
# images/v_000035/i_0012.jpg
# images/v_000035/i_0013.jpg
# images/v_000035/i_0014.jpg
# images/v_000035/i_0015.jpg
# images/v_000035/i_0016.jpg
# images/v_000035/i_0017.jpg
# images/v_000035/i_0018.jpg
# images/v_000035/i_0019.jpg
# images/v_000035/i_0020.jpg
# images/v_000035/i_0021.jpg
# images/v_000035/i_0022.jpg
# images/v_000035/i_0023.jpg
# images/v_000035/i_0024.jpg
# images/v_000035/i_0025.jpg
# images/v_000036/
# images/v_000036/i_0001.jpg
# images/v_000036/i_0002.jpg
# images/v_000036/i_0003.jpg
# images/v_000036/i_0004.jpg
# images/v_000036/i_0005.jpg
# images/v_000036/i_0006.jpg
# images/v_000036/i_0007.jpg
# images/v_000036/i_0008.jpg
# images/v_000036/i_0009.jpg
# images/v_000036/i_0010.jpg
# images/v_000036/i_0011.jpg
# images/v_000036/i_0012.jpg
# images/v_000036/i_0013.jpg
# images/v_000036/i_0014.jpg
# images/v_000036/i_0015.jpg
# images/v_000036/i_0016.jpg
# images/v_000036/i_0017.jpg
# images/v_000036/i_0018.jpg
# images/v_000036/i_0019.jpg
# images/v_000036/i_0020.jpg
# images/v_000036/i_0021.jpg
# images/v_000036/i_0022.jpg
# images/v_000036/i_0023.jpg
# images/v_000036/i_0024.jpg
# images/v_000036/i_0025.jpg
# images/v_000037/
# images/v_000037/i_0001.jpg
# images/v_000037/i_0002.jpg
# images/v_000037/i_0003.jpg
# images/v_000037/i_0004.jpg
# images/v_000037/i_0005.jpg
# images/v_000037/i_0006.jpg
# images/v_000037/i_0007.jpg
# images/v_000037/i_0008.jpg
# images/v_000037/i_0009.jpg
# images/v_000037/i_0010.jpg
# images/v_000037/i_0011.jpg
# images/v_000037/i_0012.jpg
# images/v_000037/i_0013.jpg
# images/v_000037/i_0014.jpg
# images/v_000037/i_0015.jpg
# images/v_000037/i_0016.jpg
# images/v_000037/i_0017.jpg
# images/v_000037/i_0018.jpg
# images/v_000037/i_0019.jpg
# images/v_000037/i_0020.jpg
# images/v_000037/i_0021.jpg
# images/v_000037/i_0022.jpg
# images/v_000037/i_0023.jpg
# images/v_000037/i_0024.jpg
# images/v_000037/i_0025.jpg
# images/v_000038/
# images/v_000038/i_0001.jpg
# images/v_000038/i_0002.jpg
# images/v_000038/i_0003.jpg
# images/v_000038/i_0004.jpg
# images/v_000038/i_0005.jpg
# images/v_000038/i_0006.jpg
# images/v_000038/i_0007.jpg
# images/v_000038/i_0008.jpg
# images/v_000038/i_0009.jpg
# images/v_000038/i_0010.jpg
# images/v_000038/i_0011.jpg
# images/v_000038/i_0012.jpg
# images/v_000038/i_0013.jpg
# images/v_000038/i_0014.jpg
# images/v_000038/i_0015.jpg
# images/v_000038/i_0016.jpg
# images/v_000038/i_0017.jpg
# images/v_000038/i_0018.jpg
# images/v_000038/i_0019.jpg
# images/v_000038/i_0020.jpg
# images/v_000038/i_0021.jpg
# images/v_000038/i_0022.jpg
# images/v_000038/i_0023.jpg
# images/v_000038/i_0024.jpg
# images/v_000038/i_0025.jpg
# images/v_000039/
# images/v_000039/i_0001.jpg
# images/v_000039/i_0002.jpg
# images/v_000039/i_0003.jpg
# images/v_000039/i_0004.jpg
# images/v_000039/i_0005.jpg
# images/v_000039/i_0006.jpg
# images/v_000039/i_0007.jpg
# images/v_000039/i_0008.jpg
# images/v_000039/i_0009.jpg
# images/v_000039/i_0010.jpg
# images/v_000039/i_0011.jpg
# images/v_000039/i_0012.jpg
# images/v_000039/i_0013.jpg
# images/v_000039/i_0014.jpg
# images/v_000039/i_0015.jpg
# images/v_000039/i_0016.jpg
# images/v_000039/i_0017.jpg
# images/v_000039/i_0018.jpg
# images/v_000039/i_0019.jpg
# images/v_000039/i_0020.jpg
# images/v_000039/i_0021.jpg
# images/v_000039/i_0022.jpg
# images/v_000039/i_0023.jpg
# images/v_000039/i_0024.jpg
# images/v_000039/i_0025.jpg
# images/v_000040/
# images/v_000040/i_0001.jpg
# images/v_000040/i_0002.jpg
# images/v_000040/i_0003.jpg
# images/v_000040/i_0004.jpg
# images/v_000040/i_0005.jpg
# images/v_000040/i_0006.jpg
# images/v_000040/i_0007.jpg
# images/v_000040/i_0008.jpg
# images/v_000040/i_0009.jpg
# images/v_000040/i_0010.jpg
# images/v_000040/i_0011.jpg
# images/v_000040/i_0012.jpg
# images/v_000040/i_0013.jpg
# images/v_000040/i_0014.jpg
# images/v_000040/i_0015.jpg
# images/v_000040/i_0016.jpg
# images/v_000040/i_0017.jpg
# images/v_000040/i_0018.jpg
# images/v_000040/i_0019.jpg
# images/v_000040/i_0020.jpg
# images/v_000040/i_0021.jpg
# images/v_000040/i_0022.jpg
# images/v_000040/i_0023.jpg
# images/v_000040/i_0024.jpg
# images/v_000040/i_0025.jpg
# images/v_000041/
# images/v_000041/i_0001.jpg
# images/v_000041/i_0002.jpg
# images/v_000041/i_0003.jpg
# images/v_000041/i_0004.jpg
# images/v_000041/i_0005.jpg
# images/v_000041/i_0006.jpg
# images/v_000041/i_0007.jpg
# images/v_000041/i_0008.jpg
# images/v_000041/i_0009.jpg
# images/v_000041/i_0010.jpg
# images/v_000041/i_0011.jpg
# images/v_000041/i_0012.jpg
# images/v_000041/i_0013.jpg
# images/v_000041/i_0014.jpg
# images/v_000041/i_0015.jpg
# images/v_000041/i_0016.jpg
# images/v_000041/i_0017.jpg
# images/v_000041/i_0018.jpg
# images/v_000041/i_0019.jpg
# images/v_000041/i_0020.jpg
# images/v_000041/i_0021.jpg
# images/v_000041/i_0022.jpg
# images/v_000041/i_0023.jpg
# images/v_000041/i_0024.jpg
# images/v_000041/i_0025.jpg
# images/v_000042/
# images/v_000042/i_0001.jpg
# images/v_000042/i_0002.jpg
# images/v_000042/i_0003.jpg
# images/v_000042/i_0004.jpg
# images/v_000042/i_0005.jpg
# images/v_000042/i_0006.jpg
# images/v_000042/i_0007.jpg
# images/v_000042/i_0008.jpg
# images/v_000042/i_0009.jpg
# images/v_000042/i_0010.jpg
# images/v_000042/i_0011.jpg
# images/v_000042/i_0012.jpg
# images/v_000042/i_0013.jpg
# images/v_000042/i_0014.jpg
# images/v_000042/i_0015.jpg
# images/v_000042/i_0016.jpg
# images/v_000042/i_0017.jpg
# images/v_000042/i_0018.jpg
# images/v_000042/i_0019.jpg
# images/v_000042/i_0020.jpg
# images/v_000042/i_0021.jpg
# images/v_000042/i_0022.jpg
# images/v_000042/i_0023.jpg
# images/v_000042/i_0024.jpg
# images/v_000042/i_0025.jpg
# images/v_000043/
# images/v_000043/i_0001.jpg
# images/v_000043/i_0002.jpg
# images/v_000043/i_0003.jpg
# images/v_000043/i_0004.jpg
# images/v_000043/i_0005.jpg
# images/v_000043/i_0006.jpg
# images/v_000043/i_0007.jpg
# images/v_000043/i_0008.jpg
# images/v_000043/i_0009.jpg
# images/v_000043/i_0010.jpg
# images/v_000043/i_0011.jpg
# images/v_000043/i_0012.jpg
# images/v_000043/i_0013.jpg
# images/v_000043/i_0014.jpg
# images/v_000043/i_0015.jpg
# images/v_000043/i_0016.jpg
# images/v_000043/i_0017.jpg
# images/v_000043/i_0018.jpg
# images/v_000043/i_0019.jpg
# images/v_000043/i_0020.jpg
# images/v_000043/i_0021.jpg
# images/v_000043/i_0022.jpg
# images/v_000043/i_0023.jpg
# images/v_000043/i_0024.jpg
# images/v_000043/i_0025.jpg
# images/v_000044/
# images/v_000044/i_0001.jpg
# images/v_000044/i_0002.jpg
# images/v_000044/i_0003.jpg
# images/v_000044/i_0004.jpg
# images/v_000044/i_0005.jpg
# images/v_000044/i_0006.jpg
# images/v_000044/i_0007.jpg
# images/v_000044/i_0008.jpg
# images/v_000044/i_0009.jpg
# images/v_000044/i_0010.jpg
# images/v_000044/i_0011.jpg
# images/v_000044/i_0012.jpg
# images/v_000044/i_0013.jpg
# images/v_000044/i_0014.jpg
# images/v_000044/i_0015.jpg
# images/v_000044/i_0016.jpg
# images/v_000044/i_0017.jpg
# images/v_000044/i_0018.jpg
# images/v_000044/i_0019.jpg
# images/v_000044/i_0020.jpg
# images/v_000044/i_0021.jpg
# images/v_000044/i_0022.jpg
# images/v_000044/i_0023.jpg
# images/v_000044/i_0024.jpg
# images/v_000044/i_0025.jpg
# images/v_000045/
# images/v_000045/i_0001.jpg
# images/v_000045/i_0002.jpg
# images/v_000045/i_0003.jpg
# images/v_000045/i_0004.jpg
# images/v_000045/i_0005.jpg
# images/v_000045/i_0006.jpg
# images/v_000045/i_0007.jpg
# images/v_000045/i_0008.jpg
# images/v_000045/i_0009.jpg
# images/v_000045/i_0010.jpg
# images/v_000045/i_0011.jpg
# images/v_000045/i_0012.jpg
# images/v_000045/i_0013.jpg
# images/v_000045/i_0014.jpg
# images/v_000045/i_0015.jpg
# images/v_000045/i_0016.jpg
# images/v_000045/i_0017.jpg
# images/v_000045/i_0018.jpg
# images/v_000045/i_0019.jpg
# images/v_000045/i_0020.jpg
# images/v_000045/i_0021.jpg
# images/v_000045/i_0022.jpg
# images/v_000045/i_0023.jpg
# images/v_000045/i_0024.jpg
# images/v_000045/i_0025.jpg
# images/v_000046/
# images/v_000046/i_0001.jpg
# images/v_000046/i_0002.jpg
# images/v_000046/i_0003.jpg
# images/v_000046/i_0004.jpg
# images/v_000046/i_0005.jpg
# images/v_000046/i_0006.jpg
# images/v_000046/i_0007.jpg
# images/v_000046/i_0008.jpg
# images/v_000046/i_0009.jpg
# images/v_000046/i_0010.jpg
# images/v_000046/i_0011.jpg
# images/v_000046/i_0012.jpg
# images/v_000046/i_0013.jpg
# images/v_000046/i_0014.jpg
# images/v_000046/i_0015.jpg
# images/v_000046/i_0016.jpg
# images/v_000046/i_0017.jpg
# images/v_000046/i_0018.jpg
# images/v_000046/i_0019.jpg
# images/v_000046/i_0020.jpg
# images/v_000046/i_0021.jpg
# images/v_000046/i_0022.jpg
# images/v_000046/i_0023.jpg
# images/v_000046/i_0024.jpg
# images/v_000046/i_0025.jpg
# images/v_000047/
# images/v_000047/i_0001.jpg
# images/v_000047/i_0002.jpg
# images/v_000047/i_0003.jpg
# images/v_000047/i_0004.jpg
# images/v_000047/i_0005.jpg
# images/v_000047/i_0006.jpg
# images/v_000047/i_0007.jpg
# images/v_000047/i_0008.jpg
# images/v_000047/i_0009.jpg
# images/v_000047/i_0010.jpg
# images/v_000047/i_0011.jpg
# images/v_000047/i_0012.jpg
# images/v_000047/i_0013.jpg
# images/v_000047/i_0014.jpg
# images/v_000047/i_0015.jpg
# images/v_000047/i_0016.jpg
# images/v_000047/i_0017.jpg
# images/v_000047/i_0018.jpg
# images/v_000047/i_0019.jpg
# images/v_000047/i_0020.jpg
# images/v_000047/i_0021.jpg
# images/v_000047/i_0022.jpg
# images/v_000047/i_0023.jpg
# images/v_000047/i_0024.jpg
# images/v_000047/i_0025.jpg
# images/v_000048/
# images/v_000048/i_0001.jpg
# images/v_000048/i_0002.jpg
# images/v_000048/i_0003.jpg
# images/v_000048/i_0004.jpg
# images/v_000048/i_0005.jpg
# images/v_000048/i_0006.jpg
# images/v_000048/i_0007.jpg
# images/v_000048/i_0008.jpg
# images/v_000048/i_0009.jpg
# images/v_000048/i_0010.jpg
# images/v_000048/i_0011.jpg
# images/v_000048/i_0012.jpg
# images/v_000048/i_0013.jpg
# images/v_000048/i_0014.jpg
# images/v_000048/i_0015.jpg
# images/v_000048/i_0016.jpg
# images/v_000048/i_0017.jpg
# images/v_000048/i_0018.jpg
# images/v_000048/i_0019.jpg
# images/v_000048/i_0020.jpg
# images/v_000048/i_0021.jpg
# images/v_000048/i_0022.jpg
# images/v_000048/i_0023.jpg
# images/v_000048/i_0024.jpg
# images/v_000048/i_0025.jpg
# images/v_000049/
# images/v_000049/i_0001.jpg
# images/v_000049/i_0002.jpg
# images/v_000049/i_0003.jpg
# images/v_000049/i_0004.jpg
# images/v_000049/i_0005.jpg
# images/v_000049/i_0006.jpg
# images/v_000049/i_0007.jpg
# images/v_000049/i_0008.jpg
# images/v_000049/i_0009.jpg
# images/v_000049/i_0010.jpg
# images/v_000049/i_0011.jpg
# images/v_000049/i_0012.jpg
# images/v_000049/i_0013.jpg
# images/v_000049/i_0014.jpg
# images/v_000049/i_0015.jpg
# images/v_000049/i_0016.jpg
# images/v_000049/i_0017.jpg
# images/v_000049/i_0018.jpg
# images/v_000049/i_0019.jpg
# images/v_000049/i_0020.jpg
# images/v_000049/i_0021.jpg
# images/v_000049/i_0022.jpg
# images/v_000049/i_0023.jpg
# images/v_000049/i_0024.jpg
# images/v_000049/i_0025.jpg
# images/v_000050/
# images/v_000050/i_0001.jpg
# images/v_000050/i_0002.jpg
# images/v_000050/i_0003.jpg
# images/v_000050/i_0004.jpg
# images/v_000050/i_0005.jpg
# images/v_000050/i_0006.jpg
# images/v_000050/i_0007.jpg
# images/v_000050/i_0008.jpg
# images/v_000050/i_0009.jpg
# images/v_000050/i_0010.jpg
# images/v_000050/i_0011.jpg
# images/v_000050/i_0012.jpg
# images/v_000050/i_0013.jpg
# images/v_000050/i_0014.jpg
# images/v_000050/i_0015.jpg
# images/v_000050/i_0016.jpg
# images/v_000050/i_0017.jpg
# images/v_000050/i_0018.jpg
# images/v_000050/i_0019.jpg
# images/v_000050/i_0020.jpg
# images/v_000050/i_0021.jpg
# images/v_000050/i_0022.jpg
# images/v_000050/i_0023.jpg
# images/v_000050/i_0024.jpg
# images/v_000050/i_0025.jpg
# images/v_000051/
# images/v_000051/i_0001.jpg
# images/v_000051/i_0002.jpg
# images/v_000051/i_0003.jpg
# images/v_000051/i_0004.jpg
# images/v_000051/i_0005.jpg
# images/v_000051/i_0006.jpg
# images/v_000051/i_0007.jpg
# images/v_000051/i_0008.jpg
# images/v_000051/i_0009.jpg
# images/v_000051/i_0010.jpg
# images/v_000051/i_0011.jpg
# images/v_000051/i_0012.jpg
# images/v_000051/i_0013.jpg
# images/v_000051/i_0014.jpg
# images/v_000051/i_0015.jpg
# images/v_000051/i_0016.jpg
# images/v_000051/i_0017.jpg
# images/v_000051/i_0018.jpg
# images/v_000051/i_0019.jpg
# images/v_000051/i_0020.jpg
# images/v_000051/i_0021.jpg
# images/v_000051/i_0022.jpg
# images/v_000051/i_0023.jpg
# images/v_000051/i_0024.jpg
# images/v_000051/i_0025.jpg
# images/v_000052/
# images/v_000052/i_0001.jpg
# images/v_000052/i_0002.jpg
# images/v_000052/i_0003.jpg
# images/v_000052/i_0004.jpg
# images/v_000052/i_0005.jpg
# images/v_000052/i_0006.jpg
# images/v_000052/i_0007.jpg
# images/v_000052/i_0008.jpg
# images/v_000052/i_0009.jpg
# images/v_000052/i_0010.jpg
# images/v_000052/i_0011.jpg
# images/v_000052/i_0012.jpg
# images/v_000052/i_0013.jpg
# images/v_000052/i_0014.jpg
# images/v_000052/i_0015.jpg
# images/v_000052/i_0016.jpg
# images/v_000052/i_0017.jpg
# images/v_000052/i_0018.jpg
# images/v_000052/i_0019.jpg
# images/v_000052/i_0020.jpg
# images/v_000052/i_0021.jpg
# images/v_000052/i_0022.jpg
# images/v_000052/i_0023.jpg
# images/v_000052/i_0024.jpg
# images/v_000052/i_0025.jpg
# images/v_000053/
# images/v_000053/i_0001.jpg
# images/v_000053/i_0002.jpg
# images/v_000053/i_0003.jpg
# images/v_000053/i_0004.jpg
# images/v_000053/i_0005.jpg
# images/v_000053/i_0006.jpg
# images/v_000053/i_0007.jpg
# images/v_000053/i_0008.jpg
# images/v_000053/i_0009.jpg
# images/v_000053/i_0010.jpg
# images/v_000053/i_0011.jpg
# images/v_000053/i_0012.jpg
# images/v_000053/i_0013.jpg
# images/v_000053/i_0014.jpg
# images/v_000053/i_0015.jpg
# images/v_000053/i_0016.jpg
# images/v_000053/i_0017.jpg
# images/v_000053/i_0018.jpg
# images/v_000053/i_0019.jpg
# images/v_000053/i_0020.jpg
# images/v_000053/i_0021.jpg
# images/v_000053/i_0022.jpg
# images/v_000053/i_0023.jpg
# images/v_000053/i_0024.jpg
# images/v_000053/i_0025.jpg
# images/v_000054/
# images/v_000054/i_0001.jpg
# images/v_000054/i_0002.jpg
# images/v_000054/i_0003.jpg
# images/v_000054/i_0004.jpg
# images/v_000054/i_0005.jpg
# images/v_000054/i_0006.jpg
# images/v_000054/i_0007.jpg
# images/v_000054/i_0008.jpg
# images/v_000054/i_0009.jpg
# images/v_000054/i_0010.jpg
# images/v_000054/i_0011.jpg
# images/v_000054/i_0012.jpg
# images/v_000054/i_0013.jpg
# images/v_000054/i_0014.jpg
# images/v_000054/i_0015.jpg
# images/v_000054/i_0016.jpg
# images/v_000054/i_0017.jpg
# images/v_000054/i_0018.jpg
# images/v_000054/i_0019.jpg
# images/v_000054/i_0020.jpg
# images/v_000054/i_0021.jpg
# images/v_000054/i_0022.jpg
# images/v_000054/i_0023.jpg
# images/v_000054/i_0024.jpg
# images/v_000054/i_0025.jpg
# images/v_000055/
# images/v_000055/i_0001.jpg
# images/v_000055/i_0002.jpg
# images/v_000055/i_0003.jpg
# images/v_000055/i_0004.jpg
# images/v_000055/i_0005.jpg
# images/v_000055/i_0006.jpg
# images/v_000055/i_0007.jpg
# images/v_000055/i_0008.jpg
# images/v_000055/i_0009.jpg
# images/v_000055/i_0010.jpg
# images/v_000055/i_0011.jpg
# images/v_000055/i_0012.jpg
# images/v_000055/i_0013.jpg
# images/v_000055/i_0014.jpg
# images/v_000055/i_0015.jpg
# images/v_000055/i_0016.jpg
# images/v_000055/i_0017.jpg
# images/v_000055/i_0018.jpg
# images/v_000055/i_0019.jpg
# images/v_000055/i_0020.jpg
# images/v_000055/i_0021.jpg
# images/v_000055/i_0022.jpg
# images/v_000055/i_0023.jpg
# images/v_000055/i_0024.jpg
# images/v_000055/i_0025.jpg
# images/v_000056/
# images/v_000056/i_0001.jpg
# images/v_000056/i_0002.jpg
# images/v_000056/i_0003.jpg
# images/v_000056/i_0004.jpg
# images/v_000056/i_0005.jpg
# images/v_000056/i_0006.jpg
# images/v_000056/i_0007.jpg
# images/v_000056/i_0008.jpg
# images/v_000056/i_0009.jpg
# images/v_000056/i_0010.jpg
# images/v_000056/i_0011.jpg
# images/v_000056/i_0012.jpg
# images/v_000056/i_0013.jpg
# images/v_000056/i_0014.jpg
# images/v_000056/i_0015.jpg
# images/v_000056/i_0016.jpg
# images/v_000056/i_0017.jpg
# images/v_000056/i_0018.jpg
# images/v_000056/i_0019.jpg
# images/v_000056/i_0020.jpg
# images/v_000056/i_0021.jpg
# images/v_000056/i_0022.jpg
# images/v_000056/i_0023.jpg
# images/v_000056/i_0024.jpg
# images/v_000056/i_0025.jpg
# images/v_000057/
# images/v_000057/i_0001.jpg
# images/v_000057/i_0002.jpg
# images/v_000057/i_0003.jpg
# images/v_000057/i_0004.jpg
# images/v_000057/i_0005.jpg
# images/v_000057/i_0006.jpg
# images/v_000057/i_0007.jpg
# images/v_000057/i_0008.jpg
# images/v_000057/i_0009.jpg
# images/v_000057/i_0010.jpg
# images/v_000057/i_0011.jpg
# images/v_000057/i_0012.jpg
# images/v_000057/i_0013.jpg
# images/v_000057/i_0014.jpg
# images/v_000057/i_0015.jpg
# images/v_000057/i_0016.jpg
# images/v_000057/i_0017.jpg
# images/v_000057/i_0018.jpg
# images/v_000057/i_0019.jpg
# images/v_000057/i_0020.jpg
# images/v_000057/i_0021.jpg
# images/v_000057/i_0022.jpg
# images/v_000057/i_0023.jpg
# images/v_000057/i_0024.jpg
# images/v_000057/i_0025.jpg
# images/v_000058/
# images/v_000058/i_0001.jpg
# images/v_000058/i_0002.jpg
# images/v_000058/i_0003.jpg
# images/v_000058/i_0004.jpg
# images/v_000058/i_0005.jpg
# images/v_000058/i_0006.jpg
# images/v_000058/i_0007.jpg
# images/v_000058/i_0008.jpg
# images/v_000058/i_0009.jpg
# images/v_000058/i_0010.jpg
# images/v_000058/i_0011.jpg
# images/v_000058/i_0012.jpg
# images/v_000058/i_0013.jpg
# images/v_000058/i_0014.jpg
# images/v_000058/i_0015.jpg
# images/v_000058/i_0016.jpg
# images/v_000058/i_0017.jpg
# images/v_000058/i_0018.jpg
# images/v_000058/i_0019.jpg
# images/v_000058/i_0020.jpg
# images/v_000058/i_0021.jpg
# images/v_000058/i_0022.jpg
# images/v_000058/i_0023.jpg
# images/v_000058/i_0024.jpg
# images/v_000058/i_0025.jpg
# images/v_000059/
# images/v_000059/i_0001.jpg
# images/v_000059/i_0002.jpg
# images/v_000059/i_0003.jpg
# images/v_000059/i_0004.jpg
# images/v_000059/i_0005.jpg
# images/v_000059/i_0006.jpg
# images/v_000059/i_0007.jpg
# images/v_000059/i_0008.jpg
# images/v_000059/i_0009.jpg
# images/v_000059/i_0010.jpg
# images/v_000059/i_0011.jpg
# images/v_000059/i_0012.jpg
# images/v_000059/i_0013.jpg
# images/v_000059/i_0014.jpg
# images/v_000059/i_0015.jpg
# images/v_000059/i_0016.jpg
# images/v_000059/i_0017.jpg
# images/v_000059/i_0018.jpg
# images/v_000059/i_0019.jpg
# images/v_000059/i_0020.jpg
# images/v_000059/i_0021.jpg
# images/v_000059/i_0022.jpg
# images/v_000059/i_0023.jpg
# images/v_000059/i_0024.jpg
# images/v_000059/i_0025.jpg
# images/v_000060/
# images/v_000060/i_0001.jpg
# images/v_000060/i_0002.jpg
# images/v_000060/i_0003.jpg
# images/v_000060/i_0004.jpg
# images/v_000060/i_0005.jpg
# images/v_000060/i_0006.jpg
# images/v_000060/i_0007.jpg
# images/v_000060/i_0008.jpg
# images/v_000060/i_0009.jpg
# images/v_000060/i_0010.jpg
# images/v_000060/i_0011.jpg
# images/v_000060/i_0012.jpg
# images/v_000060/i_0013.jpg
# images/v_000060/i_0014.jpg
# images/v_000060/i_0015.jpg
# images/v_000060/i_0016.jpg
# images/v_000060/i_0017.jpg
# images/v_000060/i_0018.jpg
# images/v_000060/i_0019.jpg
# images/v_000060/i_0020.jpg
# images/v_000060/i_0021.jpg
# images/v_000060/i_0022.jpg
# images/v_000060/i_0023.jpg
# images/v_000060/i_0024.jpg
# images/v_000060/i_0025.jpg
# images/v_000061/
# images/v_000061/i_0001.jpg
# images/v_000061/i_0002.jpg
# images/v_000061/i_0003.jpg
# images/v_000061/i_0004.jpg
# images/v_000061/i_0005.jpg
# images/v_000061/i_0006.jpg
# images/v_000061/i_0007.jpg
# images/v_000061/i_0008.jpg
# images/v_000061/i_0009.jpg
# images/v_000061/i_0010.jpg
# images/v_000061/i_0011.jpg
# images/v_000061/i_0012.jpg
# images/v_000061/i_0013.jpg
# images/v_000061/i_0014.jpg
# images/v_000061/i_0015.jpg
# images/v_000061/i_0016.jpg
# images/v_000061/i_0017.jpg
# images/v_000061/i_0018.jpg
# images/v_000061/i_0019.jpg
# images/v_000061/i_0020.jpg
# images/v_000061/i_0021.jpg
# images/v_000061/i_0022.jpg
# images/v_000061/i_0023.jpg
# images/v_000061/i_0024.jpg
# images/v_000061/i_0025.jpg
# images/v_000062/
# images/v_000062/i_0001.jpg
# images/v_000062/i_0002.jpg
# images/v_000062/i_0003.jpg
# images/v_000062/i_0004.jpg
# images/v_000062/i_0005.jpg
# images/v_000062/i_0006.jpg
# images/v_000062/i_0007.jpg
# images/v_000062/i_0008.jpg
# images/v_000062/i_0009.jpg
# images/v_000062/i_0010.jpg
# images/v_000062/i_0011.jpg
# images/v_000062/i_0012.jpg
# images/v_000062/i_0013.jpg
# images/v_000062/i_0014.jpg
# images/v_000062/i_0015.jpg
# images/v_000062/i_0016.jpg
# images/v_000062/i_0017.jpg
# images/v_000062/i_0018.jpg
# images/v_000062/i_0019.jpg
# images/v_000062/i_0020.jpg
# images/v_000062/i_0021.jpg
# images/v_000062/i_0022.jpg
# images/v_000062/i_0023.jpg
# images/v_000062/i_0024.jpg
# images/v_000062/i_0025.jpg
# images/v_000063/
# images/v_000063/i_0001.jpg
# images/v_000063/i_0002.jpg
# images/v_000063/i_0003.jpg
# images/v_000063/i_0004.jpg
# images/v_000063/i_0005.jpg
# images/v_000063/i_0006.jpg
# images/v_000063/i_0007.jpg
# images/v_000063/i_0008.jpg
# images/v_000063/i_0009.jpg
# images/v_000063/i_0010.jpg
# images/v_000063/i_0011.jpg
# images/v_000063/i_0012.jpg
# images/v_000063/i_0013.jpg
# images/v_000063/i_0014.jpg
# images/v_000063/i_0015.jpg
# images/v_000063/i_0016.jpg
# images/v_000063/i_0017.jpg
# images/v_000063/i_0018.jpg
# images/v_000063/i_0019.jpg
# images/v_000063/i_0020.jpg
# images/v_000063/i_0021.jpg
# images/v_000063/i_0022.jpg
# images/v_000063/i_0023.jpg
# images/v_000063/i_0024.jpg
# images/v_000063/i_0025.jpg
# images/v_000064/
# images/v_000064/i_0001.jpg
# images/v_000064/i_0002.jpg
# images/v_000064/i_0003.jpg
# images/v_000064/i_0004.jpg
# images/v_000064/i_0005.jpg
# images/v_000064/i_0006.jpg
# images/v_000064/i_0007.jpg
# images/v_000064/i_0008.jpg
# images/v_000064/i_0009.jpg
# images/v_000064/i_0010.jpg
# images/v_000064/i_0011.jpg
# images/v_000064/i_0012.jpg
# images/v_000064/i_0013.jpg
# images/v_000064/i_0014.jpg
# images/v_000064/i_0015.jpg
# images/v_000064/i_0016.jpg
# images/v_000064/i_0017.jpg
# images/v_000064/i_0018.jpg
# images/v_000064/i_0019.jpg
# images/v_000064/i_0020.jpg
# images/v_000064/i_0021.jpg
# images/v_000064/i_0022.jpg
# images/v_000064/i_0023.jpg
# images/v_000064/i_0024.jpg
# images/v_000064/i_0025.jpg
# images/v_000065/
# images/v_000065/i_0001.jpg
# images/v_000065/i_0002.jpg
# images/v_000065/i_0003.jpg
# images/v_000065/i_0004.jpg
# images/v_000065/i_0005.jpg
# images/v_000065/i_0006.jpg
# images/v_000065/i_0007.jpg
# images/v_000065/i_0008.jpg
# images/v_000065/i_0009.jpg
# images/v_000065/i_0010.jpg
# images/v_000065/i_0011.jpg
# images/v_000065/i_0012.jpg
# images/v_000065/i_0013.jpg
# images/v_000065/i_0014.jpg
# images/v_000065/i_0015.jpg
# images/v_000065/i_0016.jpg
# images/v_000065/i_0017.jpg
# images/v_000065/i_0018.jpg
# images/v_000065/i_0019.jpg
# images/v_000065/i_0020.jpg
# images/v_000065/i_0021.jpg
# images/v_000065/i_0022.jpg
# images/v_000065/i_0023.jpg
# images/v_000065/i_0024.jpg
# images/v_000065/i_0025.jpg
# images/v_000066/
# images/v_000066/i_0001.jpg
# images/v_000066/i_0002.jpg
# images/v_000066/i_0003.jpg
# images/v_000066/i_0004.jpg
# images/v_000066/i_0005.jpg
# images/v_000066/i_0006.jpg
# images/v_000066/i_0007.jpg
# images/v_000066/i_0008.jpg
# images/v_000066/i_0009.jpg
# images/v_000066/i_0010.jpg
# images/v_000066/i_0011.jpg
# images/v_000066/i_0012.jpg
# images/v_000066/i_0013.jpg
# images/v_000066/i_0014.jpg
# images/v_000066/i_0015.jpg
# images/v_000066/i_0016.jpg
# images/v_000066/i_0017.jpg
# images/v_000066/i_0018.jpg
# images/v_000066/i_0019.jpg
# images/v_000066/i_0020.jpg
# images/v_000066/i_0021.jpg
# images/v_000066/i_0022.jpg
# images/v_000066/i_0023.jpg
# images/v_000066/i_0024.jpg
# images/v_000066/i_0025.jpg
# images/v_000067/
# images/v_000067/i_0001.jpg
# images/v_000067/i_0002.jpg
# images/v_000067/i_0003.jpg
# images/v_000067/i_0004.jpg
# images/v_000067/i_0005.jpg
# images/v_000067/i_0006.jpg
# images/v_000067/i_0007.jpg
# images/v_000067/i_0008.jpg
# images/v_000067/i_0009.jpg
# images/v_000067/i_0010.jpg
# images/v_000067/i_0011.jpg
# images/v_000067/i_0012.jpg
# images/v_000067/i_0013.jpg
# images/v_000067/i_0014.jpg
# images/v_000067/i_0015.jpg
# images/v_000067/i_0016.jpg
# images/v_000067/i_0017.jpg
# images/v_000067/i_0018.jpg
# images/v_000067/i_0019.jpg
# images/v_000067/i_0020.jpg
# images/v_000067/i_0021.jpg
# images/v_000067/i_0022.jpg
# images/v_000067/i_0023.jpg
# images/v_000067/i_0024.jpg
# images/v_000067/i_0025.jpg
# images/v_000068/
# images/v_000068/i_0001.jpg
# images/v_000068/i_0002.jpg
# images/v_000068/i_0003.jpg
# images/v_000068/i_0004.jpg
# images/v_000068/i_0005.jpg
# images/v_000068/i_0006.jpg
# images/v_000068/i_0007.jpg
# images/v_000068/i_0008.jpg
# images/v_000068/i_0009.jpg
# images/v_000068/i_0010.jpg
# images/v_000068/i_0011.jpg
# images/v_000068/i_0012.jpg
# images/v_000068/i_0013.jpg
# images/v_000068/i_0014.jpg
# images/v_000068/i_0015.jpg
# images/v_000068/i_0016.jpg
# images/v_000068/i_0017.jpg
# images/v_000068/i_0018.jpg
# images/v_000068/i_0019.jpg
# images/v_000068/i_0020.jpg
# images/v_000068/i_0021.jpg
# images/v_000068/i_0022.jpg
# images/v_000068/i_0023.jpg
# images/v_000068/i_0024.jpg
# images/v_000068/i_0025.jpg
# images/v_000069/
# images/v_000069/i_0001.jpg
# images/v_000069/i_0002.jpg
# images/v_000069/i_0003.jpg
# images/v_000069/i_0004.jpg
# images/v_000069/i_0005.jpg
# images/v_000069/i_0006.jpg
# images/v_000069/i_0007.jpg
# images/v_000069/i_0008.jpg
# images/v_000069/i_0009.jpg
# images/v_000069/i_0010.jpg
# images/v_000069/i_0011.jpg
# images/v_000069/i_0012.jpg
# images/v_000069/i_0013.jpg
# images/v_000069/i_0014.jpg
# images/v_000069/i_0015.jpg
# images/v_000069/i_0016.jpg
# images/v_000069/i_0017.jpg
# images/v_000069/i_0018.jpg
# images/v_000069/i_0019.jpg
# images/v_000069/i_0020.jpg
# images/v_000069/i_0021.jpg
# images/v_000069/i_0022.jpg
# images/v_000069/i_0023.jpg
# images/v_000069/i_0024.jpg
# images/v_000069/i_0025.jpg
# images/v_000070/
# images/v_000070/i_0001.jpg
# images/v_000070/i_0002.jpg
# images/v_000070/i_0003.jpg
# images/v_000070/i_0004.jpg
# images/v_000070/i_0005.jpg
# images/v_000070/i_0006.jpg
# images/v_000070/i_0007.jpg
# images/v_000070/i_0008.jpg
# ...
# images/v_000091/i_0018.jpg
# images/v_000091/i_0019.jpg
# images/v_000091/i_0020.jpg
# images/v_000091/i_0021.jpg
# images/v_000091/i_0022.jpg
# images/v_000091/i_0023.jpg
# images/v_000091/i_0024.jpg
# images/v_000091/i_0025.jpg
# images/v_000092/
# images/v_000092/i_0001.jpg
# images/v_000092/i_0002.jpg
# images/v_000092/i_0003.jpg
# images/v_000092/i_0004.jpg
# images/v_000092/i_0005.jpg
# images/v_000092/i_0006.jpg
# images/v_000092/i_0007.jpg
# images/v_000092/i_0008.jpg
# images/v_000092/i_0009.jpg
# images/v_000092/i_0010.jpg
# images/v_000092/i_0011.jpg
# images/v_000092/i_0012.jpg
# images/v_000092/i_0013.jpg
# images/v_000092/i_0014.jpg
# images/v_000092/i_0015.jpg
# images/v_000092/i_0016.jpg
# images/v_000092/i_0017.jpg
# images/v_000092/i_0018.jpg
# images/v_000092/i_0019.jpg
# images/v_000092/i_0020.jpg
# images/v_000092/i_0021.jpg
# images/v_000092/i_0022.jpg
# images/v_000092/i_0023.jpg
# images/v_000092/i_0024.jpg
# images/v_000092/i_0025.jpg
# images/v_000093/
# images/v_000093/i_0001.jpg
# images/v_000093/i_0002.jpg
# images/v_000093/i_0003.jpg
# images/v_000093/i_0004.jpg
# images/v_000093/i_0005.jpg
# images/v_000093/i_0006.jpg
# images/v_000093/i_0007.jpg
# images/v_000093/i_0008.jpg
# images/v_000093/i_0009.jpg
# images/v_000093/i_0010.jpg
# images/v_000093/i_0011.jpg
# images/v_000093/i_0012.jpg
# images/v_000093/i_0013.jpg
# images/v_000093/i_0014.jpg
# images/v_000093/i_0015.jpg
# images/v_000093/i_0016.jpg
# images/v_000093/i_0017.jpg
# images/v_000093/i_0018.jpg
# images/v_000093/i_0019.jpg
# images/v_000093/i_0020.jpg
# images/v_000093/i_0021.jpg
# images/v_000093/i_0022.jpg
# images/v_000093/i_0023.jpg
# images/v_000093/i_0024.jpg
# images/v_000093/i_0025.jpg
# images/v_000094/
# images/v_000094/i_0001.jpg
# images/v_000094/i_0002.jpg
# images/v_000094/i_0003.jpg
# images/v_000094/i_0004.jpg
# images/v_000094/i_0005.jpg
# images/v_000094/i_0006.jpg
# images/v_000094/i_0007.jpg
# images/v_000094/i_0008.jpg
# images/v_000094/i_0009.jpg
# images/v_000094/i_0010.jpg
# images/v_000094/i_0011.jpg
# images/v_000094/i_0012.jpg
# images/v_000094/i_0013.jpg
# images/v_000094/i_0014.jpg
# images/v_000094/i_0015.jpg
# images/v_000094/i_0016.jpg
# images/v_000094/i_0017.jpg
# images/v_000094/i_0018.jpg
# images/v_000094/i_0019.jpg
# images/v_000094/i_0020.jpg
# images/v_000094/i_0021.jpg
# images/v_000094/i_0022.jpg
# images/v_000094/i_0023.jpg
# images/v_000094/i_0024.jpg
# images/v_000094/i_0025.jpg
# images/v_000095/
# images/v_000095/i_0001.jpg
# images/v_000095/i_0002.jpg
# images/v_000095/i_0003.jpg
# images/v_000095/i_0004.jpg
# images/v_000095/i_0005.jpg
# images/v_000095/i_0006.jpg
# images/v_000095/i_0007.jpg
# images/v_000095/i_0008.jpg
# images/v_000095/i_0009.jpg
# images/v_000095/i_0010.jpg
# images/v_000095/i_0011.jpg
# images/v_000095/i_0012.jpg
# images/v_000095/i_0013.jpg
# images/v_000095/i_0014.jpg
# images/v_000095/i_0015.jpg
# images/v_000095/i_0016.jpg
# images/v_000095/i_0017.jpg
# images/v_000095/i_0018.jpg
# images/v_000095/i_0019.jpg
# images/v_000095/i_0020.jpg
# images/v_000095/i_0021.jpg
# images/v_000095/i_0022.jpg
# images/v_000095/i_0023.jpg
# images/v_000095/i_0024.jpg
# images/v_000095/i_0025.jpg
# images/v_000096/
# images/v_000096/i_0001.jpg
# images/v_000096/i_0002.jpg
# images/v_000096/i_0003.jpg
# images/v_000096/i_0004.jpg
# images/v_000096/i_0005.jpg
# images/v_000096/i_0006.jpg
# images/v_000096/i_0007.jpg
# images/v_000096/i_0008.jpg
# images/v_000096/i_0009.jpg
# images/v_000096/i_0010.jpg
# images/v_000096/i_0011.jpg
# images/v_000096/i_0012.jpg
# images/v_000096/i_0013.jpg
# images/v_000096/i_0014.jpg
# images/v_000096/i_0015.jpg
# images/v_000096/i_0016.jpg
# images/v_000096/i_0017.jpg
# images/v_000096/i_0018.jpg
# images/v_000096/i_0019.jpg
# images/v_000096/i_0020.jpg
# images/v_000096/i_0021.jpg
# images/v_000096/i_0022.jpg
# images/v_000096/i_0023.jpg
# images/v_000096/i_0024.jpg
# images/v_000096/i_0025.jpg
# images/v_000097/
# images/v_000097/i_0001.jpg
# images/v_000097/i_0002.jpg
# images/v_000097/i_0003.jpg
# images/v_000097/i_0004.jpg
# images/v_000097/i_0005.jpg
# images/v_000097/i_0006.jpg
# images/v_000097/i_0007.jpg
# images/v_000097/i_0008.jpg
# images/v_000097/i_0009.jpg
# images/v_000097/i_0010.jpg
# images/v_000097/i_0011.jpg
# images/v_000097/i_0012.jpg
# images/v_000097/i_0013.jpg
# images/v_000097/i_0014.jpg
# images/v_000097/i_0015.jpg
# images/v_000097/i_0016.jpg
# images/v_000097/i_0017.jpg
# images/v_000097/i_0018.jpg
# images/v_000097/i_0019.jpg
# images/v_000097/i_0020.jpg
# images/v_000097/i_0021.jpg
# images/v_000097/i_0022.jpg
# images/v_000097/i_0023.jpg
# images/v_000097/i_0024.jpg
# images/v_000097/i_0025.jpg
# images/v_000098/
# images/v_000098/i_0001.jpg
# images/v_000098/i_0002.jpg
# images/v_000098/i_0003.jpg
# images/v_000098/i_0004.jpg
# images/v_000098/i_0005.jpg
# images/v_000098/i_0006.jpg
# images/v_000098/i_0007.jpg
# images/v_000098/i_0008.jpg
# images/v_000098/i_0009.jpg
# images/v_000098/i_0010.jpg
# images/v_000098/i_0011.jpg
# images/v_000098/i_0012.jpg
# images/v_000098/i_0013.jpg
# images/v_000098/i_0014.jpg
# images/v_000098/i_0015.jpg
# images/v_000098/i_0016.jpg
# images/v_000098/i_0017.jpg
# images/v_000098/i_0018.jpg
# images/v_000098/i_0019.jpg
# images/v_000098/i_0020.jpg
# images/v_000098/i_0021.jpg
# images/v_000098/i_0022.jpg
# images/v_000098/i_0023.jpg
# images/v_000098/i_0024.jpg
# images/v_000098/i_0025.jpg
# images/v_000099/
# images/v_000099/i_0001.jpg
# images/v_000099/i_0002.jpg
# images/v_000099/i_0003.jpg
# images/v_000099/i_0004.jpg
# images/v_000099/i_0005.jpg
# images/v_000099/i_0006.jpg
# images/v_000099/i_0007.jpg
# images/v_000099/i_0008.jpg
# images/v_000099/i_0009.jpg
# images/v_000099/i_0010.jpg
# images/v_000099/i_0011.jpg
# images/v_000099/i_0012.jpg
# images/v_000099/i_0013.jpg
# images/v_000099/i_0014.jpg
# images/v_000099/i_0015.jpg
# images/v_000099/i_0016.jpg
# images/v_000099/i_0017.jpg
# images/v_000099/i_0018.jpg
# images/v_000099/i_0019.jpg
# images/v_000099/i_0020.jpg
# images/v_000099/i_0021.jpg
# images/v_000099/i_0022.jpg
# images/v_000099/i_0023.jpg
# images/v_000099/i_0024.jpg
# images/v_000099/i_0025.jpg
# images/v_000100/
# images/v_000100/i_0001.jpg
# images/v_000100/i_0002.jpg
# images/v_000100/i_0003.jpg
# images/v_000100/i_0004.jpg
# images/v_000100/i_0005.jpg
# images/v_000100/i_0006.jpg
# images/v_000100/i_0007.jpg
# images/v_000100/i_0008.jpg
# images/v_000100/i_0009.jpg
# images/v_000100/i_0010.jpg
# images/v_000100/i_0011.jpg
# images/v_000100/i_0012.jpg
# images/v_000100/i_0013.jpg
# images/v_000100/i_0014.jpg
# images/v_000100/i_0015.jpg
# images/v_000100/i_0016.jpg
# images/v_000100/i_0017.jpg
# images/v_000100/i_0018.jpg
# images/v_000100/i_0019.jpg
# images/v_000100/i_0020.jpg
# images/v_000100/i_0021.jpg
# images/v_000100/i_0022.jpg
# images/v_000100/i_0023.jpg
# images/v_000100/i_0024.jpg
# images/v_000100/i_0025.jpg
# images/v_000101/
# images/v_000101/i_0001.jpg
# images/v_000101/i_0002.jpg
# images/v_000101/i_0003.jpg
# images/v_000101/i_0004.jpg
# images/v_000101/i_0005.jpg
# images/v_000101/i_0006.jpg
# images/v_000101/i_0007.jpg
# images/v_000101/i_0008.jpg
# images/v_000101/i_0009.jpg
# images/v_000101/i_0010.jpg
# images/v_000101/i_0011.jpg
# images/v_000101/i_0012.jpg
# images/v_000101/i_0013.jpg
# images/v_000101/i_0014.jpg
# images/v_000101/i_0015.jpg
# images/v_000101/i_0016.jpg
# images/v_000101/i_0017.jpg
# images/v_000101/i_0018.jpg
# images/v_000101/i_0019.jpg
# images/v_000101/i_0020.jpg
# images/v_000101/i_0021.jpg
# images/v_000101/i_0022.jpg
# images/v_000101/i_0023.jpg
# images/v_000101/i_0024.jpg
# images/v_000101/i_0025.jpg
# images/v_000102/
# images/v_000102/i_0001.jpg
# images/v_000102/i_0002.jpg
# images/v_000102/i_0003.jpg
# images/v_000102/i_0004.jpg
# images/v_000102/i_0005.jpg
# images/v_000102/i_0006.jpg
# images/v_000102/i_0007.jpg
# images/v_000102/i_0008.jpg
# images/v_000102/i_0009.jpg
# images/v_000102/i_0010.jpg
# images/v_000102/i_0011.jpg
# images/v_000102/i_0012.jpg
# images/v_000102/i_0013.jpg
# images/v_000102/i_0014.jpg
# images/v_000102/i_0015.jpg
# images/v_000102/i_0016.jpg
# images/v_000102/i_0017.jpg
# images/v_000102/i_0018.jpg
# images/v_000102/i_0019.jpg
# images/v_000102/i_0020.jpg
# images/v_000102/i_0021.jpg
# images/v_000102/i_0022.jpg
# images/v_000102/i_0023.jpg
# images/v_000102/i_0024.jpg
# images/v_000102/i_0025.jpg
# images/v_000103/
# images/v_000103/i_0001.jpg
# images/v_000103/i_0002.jpg
# images/v_000103/i_0003.jpg
# images/v_000103/i_0004.jpg
# images/v_000103/i_0005.jpg
# images/v_000103/i_0006.jpg
# images/v_000103/i_0007.jpg
# images/v_000103/i_0008.jpg
# images/v_000103/i_0009.jpg
# images/v_000103/i_0010.jpg
# images/v_000103/i_0011.jpg
# images/v_000103/i_0012.jpg
# images/v_000103/i_0013.jpg
# images/v_000103/i_0014.jpg
# images/v_000103/i_0015.jpg
# images/v_000103/i_0016.jpg
# images/v_000103/i_0017.jpg
# images/v_000103/i_0018.jpg
# images/v_000103/i_0019.jpg
# images/v_000103/i_0020.jpg
# images/v_000103/i_0021.jpg
# images/v_000103/i_0022.jpg
# images/v_000103/i_0023.jpg
# images/v_000103/i_0024.jpg
# images/v_000103/i_0025.jpg
# images/v_000104/
# images/v_000104/i_0001.jpg
# images/v_000104/i_0002.jpg
# images/v_000104/i_0003.jpg
# images/v_000104/i_0004.jpg
# images/v_000104/i_0005.jpg
# images/v_000104/i_0006.jpg
# images/v_000104/i_0007.jpg
# images/v_000104/i_0008.jpg
# images/v_000104/i_0009.jpg
# images/v_000104/i_0010.jpg
# images/v_000104/i_0011.jpg
# images/v_000104/i_0012.jpg
# images/v_000104/i_0013.jpg
# images/v_000104/i_0014.jpg
# images/v_000104/i_0015.jpg
# images/v_000104/i_0016.jpg
# images/v_000104/i_0017.jpg
# images/v_000104/i_0018.jpg
# images/v_000104/i_0019.jpg
# images/v_000104/i_0020.jpg
# images/v_000104/i_0021.jpg
# images/v_000104/i_0022.jpg
# images/v_000104/i_0023.jpg
# images/v_000104/i_0024.jpg
# images/v_000104/i_0025.jpg
# images/v_000105/
# images/v_000105/i_0001.jpg
# images/v_000105/i_0002.jpg
# images/v_000105/i_0003.jpg
# images/v_000105/i_0004.jpg
# images/v_000105/i_0005.jpg
# images/v_000105/i_0006.jpg
# images/v_000105/i_0007.jpg
# images/v_000105/i_0008.jpg
# images/v_000105/i_0009.jpg
# images/v_000105/i_0010.jpg
# images/v_000105/i_0011.jpg
# images/v_000105/i_0012.jpg
# images/v_000105/i_0013.jpg
# images/v_000105/i_0014.jpg
# images/v_000105/i_0015.jpg
# images/v_000105/i_0016.jpg
# images/v_000105/i_0017.jpg
# images/v_000105/i_0018.jpg
# images/v_000105/i_0019.jpg
# images/v_000105/i_0020.jpg
# images/v_000105/i_0021.jpg
# images/v_000105/i_0022.jpg
# images/v_000105/i_0023.jpg
# images/v_000105/i_0024.jpg
# images/v_000105/i_0025.jpg
# images/v_000106/
# images/v_000106/i_0001.jpg
# images/v_000106/i_0002.jpg
# images/v_000106/i_0003.jpg
# images/v_000106/i_0004.jpg
# images/v_000106/i_0005.jpg
# images/v_000106/i_0006.jpg
# images/v_000106/i_0007.jpg
# images/v_000106/i_0008.jpg
# images/v_000106/i_0009.jpg
# images/v_000106/i_0010.jpg
# images/v_000106/i_0011.jpg
# images/v_000106/i_0012.jpg
# images/v_000106/i_0013.jpg
# images/v_000106/i_0014.jpg
# images/v_000106/i_0015.jpg
# images/v_000106/i_0016.jpg
# images/v_000106/i_0017.jpg
# images/v_000106/i_0018.jpg
# images/v_000106/i_0019.jpg
# images/v_000106/i_0020.jpg
# images/v_000106/i_0021.jpg
# images/v_000106/i_0022.jpg
# images/v_000106/i_0023.jpg
# images/v_000106/i_0024.jpg
# images/v_000106/i_0025.jpg
# images/v_000107/
# images/v_000107/i_0001.jpg
# images/v_000107/i_0002.jpg
# images/v_000107/i_0003.jpg
# images/v_000107/i_0004.jpg
# images/v_000107/i_0005.jpg
# images/v_000107/i_0006.jpg
# images/v_000107/i_0007.jpg
# images/v_000107/i_0008.jpg
# images/v_000107/i_0009.jpg
# images/v_000107/i_0010.jpg
# images/v_000107/i_0011.jpg
# images/v_000107/i_0012.jpg
# images/v_000107/i_0013.jpg
# images/v_000107/i_0014.jpg
# images/v_000107/i_0015.jpg
# images/v_000107/i_0016.jpg
# images/v_000107/i_0017.jpg
# images/v_000107/i_0018.jpg
# images/v_000107/i_0019.jpg
# images/v_000107/i_0020.jpg
# images/v_000107/i_0021.jpg
# images/v_000107/i_0022.jpg
# images/v_000107/i_0023.jpg
# images/v_000107/i_0024.jpg
# images/v_000107/i_0025.jpg
# images/v_000108/
# images/v_000108/i_0001.jpg
# images/v_000108/i_0002.jpg
# images/v_000108/i_0003.jpg
# images/v_000108/i_0004.jpg
# images/v_000108/i_0005.jpg
# images/v_000108/i_0006.jpg
# images/v_000108/i_0007.jpg
# images/v_000108/i_0008.jpg
# images/v_000108/i_0009.jpg
# images/v_000108/i_0010.jpg
# images/v_000108/i_0011.jpg
# images/v_000108/i_0012.jpg
# images/v_000108/i_0013.jpg
# images/v_000108/i_0014.jpg
# images/v_000108/i_0015.jpg
# images/v_000108/i_0016.jpg
# images/v_000108/i_0017.jpg
# images/v_000108/i_0018.jpg
# images/v_000108/i_0019.jpg
# images/v_000108/i_0020.jpg
# images/v_000108/i_0021.jpg
# images/v_000108/i_0022.jpg
# images/v_000108/i_0023.jpg
# images/v_000108/i_0024.jpg
# images/v_000108/i_0025.jpg
# images/v_000109/
# images/v_000109/i_0001.jpg
# images/v_000109/i_0002.jpg
# images/v_000109/i_0003.jpg
# images/v_000109/i_0004.jpg
# images/v_000109/i_0005.jpg
# images/v_000109/i_0006.jpg
# images/v_000109/i_0007.jpg
# images/v_000109/i_0008.jpg
# images/v_000109/i_0009.jpg
# images/v_000109/i_0010.jpg
# images/v_000109/i_0011.jpg
# images/v_000109/i_0012.jpg
# images/v_000109/i_0013.jpg
# images/v_000109/i_0014.jpg
# images/v_000109/i_0015.jpg
# images/v_000109/i_0016.jpg
# images/v_000109/i_0017.jpg
# images/v_000109/i_0018.jpg
# images/v_000109/i_0019.jpg
# images/v_000109/i_0020.jpg
# images/v_000109/i_0021.jpg
# images/v_000109/i_0022.jpg
# images/v_000109/i_0023.jpg
# images/v_000109/i_0024.jpg
# images/v_000109/i_0025.jpg
# images/v_000110/
# images/v_000110/i_0001.jpg
# images/v_000110/i_0002.jpg
# images/v_000110/i_0003.jpg
# images/v_000110/i_0004.jpg
# images/v_000110/i_0005.jpg
# images/v_000110/i_0006.jpg
# images/v_000110/i_0007.jpg
# images/v_000110/i_0008.jpg
# images/v_000110/i_0009.jpg
# images/v_000110/i_0010.jpg
# images/v_000110/i_0011.jpg
# images/v_000110/i_0012.jpg
# images/v_000110/i_0013.jpg
# images/v_000110/i_0014.jpg
# images/v_000110/i_0015.jpg
# images/v_000110/i_0016.jpg
# images/v_000110/i_0017.jpg
# images/v_000110/i_0018.jpg
# images/v_000110/i_0019.jpg
# images/v_000110/i_0020.jpg
# images/v_000110/i_0021.jpg
# images/v_000110/i_0022.jpg
# images/v_000110/i_0023.jpg
# images/v_000110/i_0024.jpg
# images/v_000110/i_0025.jpg
# images/v_000111/
# images/v_000111/i_0001.jpg
# images/v_000111/i_0002.jpg
# images/v_000111/i_0003.jpg
# images/v_000111/i_0004.jpg
# images/v_000111/i_0005.jpg
# images/v_000111/i_0006.jpg
# images/v_000111/i_0007.jpg
# images/v_000111/i_0008.jpg
# images/v_000111/i_0009.jpg
# images/v_000111/i_0010.jpg
# images/v_000111/i_0011.jpg
# images/v_000111/i_0012.jpg
# images/v_000111/i_0013.jpg
# images/v_000111/i_0014.jpg
# images/v_000111/i_0015.jpg
# images/v_000111/i_0016.jpg
# images/v_000111/i_0017.jpg
# images/v_000111/i_0018.jpg
# images/v_000111/i_0019.jpg
# images/v_000111/i_0020.jpg
# images/v_000111/i_0021.jpg
# images/v_000111/i_0022.jpg
# images/v_000111/i_0023.jpg
# images/v_000111/i_0024.jpg
# images/v_000111/i_0025.jpg
# images/v_000112/
# images/v_000112/i_0001.jpg
# images/v_000112/i_0002.jpg
# images/v_000112/i_0003.jpg
# images/v_000112/i_0004.jpg
# images/v_000112/i_0005.jpg
# images/v_000112/i_0006.jpg
# images/v_000112/i_0007.jpg
# images/v_000112/i_0008.jpg
# images/v_000112/i_0009.jpg
# images/v_000112/i_0010.jpg
# images/v_000112/i_0011.jpg
# images/v_000112/i_0012.jpg
# images/v_000112/i_0013.jpg
# images/v_000112/i_0014.jpg
# images/v_000112/i_0015.jpg
# images/v_000112/i_0016.jpg
# images/v_000112/i_0017.jpg
# images/v_000112/i_0018.jpg
# images/v_000112/i_0019.jpg
# images/v_000112/i_0020.jpg
# images/v_000112/i_0021.jpg
# images/v_000112/i_0022.jpg
# images/v_000112/i_0023.jpg
# images/v_000112/i_0024.jpg
# images/v_000112/i_0025.jpg
# images/v_000113/
# images/v_000113/i_0001.jpg
# images/v_000113/i_0002.jpg
# images/v_000113/i_0003.jpg
# images/v_000113/i_0004.jpg
# images/v_000113/i_0005.jpg
# images/v_000113/i_0006.jpg
# images/v_000113/i_0007.jpg
# images/v_000113/i_0008.jpg
# images/v_000113/i_0009.jpg
# images/v_000113/i_0010.jpg
# images/v_000113/i_0011.jpg
# images/v_000113/i_0012.jpg
# images/v_000113/i_0013.jpg
# images/v_000113/i_0014.jpg
# images/v_000113/i_0015.jpg
# images/v_000113/i_0016.jpg
# images/v_000113/i_0017.jpg
# images/v_000113/i_0018.jpg
# images/v_000113/i_0019.jpg
# images/v_000113/i_0020.jpg
# images/v_000113/i_0021.jpg
# images/v_000113/i_0022.jpg
# images/v_000113/i_0023.jpg
# images/v_000113/i_0024.jpg
# images/v_000113/i_0025.jpg
# images/v_000114/
# images/v_000114/i_0001.jpg
# images/v_000114/i_0002.jpg
# images/v_000114/i_0003.jpg
# images/v_000114/i_0004.jpg
# images/v_000114/i_0005.jpg
# images/v_000114/i_0006.jpg
# images/v_000114/i_0007.jpg
# images/v_000114/i_0008.jpg
# images/v_000114/i_0009.jpg
# images/v_000114/i_0010.jpg
# images/v_000114/i_0011.jpg
# images/v_000114/i_0012.jpg
# images/v_000114/i_0013.jpg
# images/v_000114/i_0014.jpg
# images/v_000114/i_0015.jpg
# images/v_000114/i_0016.jpg
# images/v_000114/i_0017.jpg
# images/v_000114/i_0018.jpg
# images/v_000114/i_0019.jpg
# images/v_000114/i_0020.jpg

# %%
# import packages here
import cv2
import numpy as np
import matplotlib.pyplot as plt
import glob
import random 
import time
import datetime
from scipy import stats

import torch
import torchvision
import torchvision.transforms as transforms

from torch.autograd import Variable
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import pandas as pd
import os
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'

from sklearn.utils import shuffle

# %% [markdown]
# ---
# ---
# ## **Problem 1.** Feature extraction

# %%
from datetime import datetime
def load_dataset(model,batch_num=1, shuffle=False):
    
    model = model.cuda()
    train_data = []
    train_labels = []

    test_data = []
    test_labels = []


    normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    prep = transforms.Compose([ transforms.ToTensor(), normalize])
    
    path = './images/'
    annos = pd.read_csv('./annos/videos_labels_subsets.txt', sep="\t",header = None)
    annos = np.array(annos)
    class_names = annos[:,0]

    w,h = 224,224


    with torch.no_grad():
      for i in range(0,3361):
        if i%20 == 0:
          current_time = datetime.now()
          print("\nIn folder %s\n", path + class_names[i], " at time: ", current_time)


        img_path_class = glob.glob(path + class_names[i] + '/*.jpg')

        
        count = 1
        pntr = 0
        batch_size = 125
        stacked_tensor = (torch.empty([batch_size,3,h,w], dtype=torch.float)).cuda()

        for filename in img_path_class:
              
          img = cv2.imread(filename)
          [img_row,img_col,channels] = np.shape(img)
          
          crop_img_1 = torch.Tensor(prep(img[:h, :w])).float().cuda()
          #crop_img_1 = crop_img_1.permute(2,0,1).float()

          crop_img_2 = torch.Tensor(prep(img[img_row-h:, :w])).float().cuda()
          #crop_img_2 = crop_img_2.permute(2,0,1).float()


          crop_img_3 = torch.Tensor(prep(img[:h, img_col-w:])).float().cuda()
          #crop_img_3 = crop_img_3.permute(2,0,1).float()


          crop_img_4 = torch.Tensor(prep(img[img_row-h:, img_col-w:])).float().cuda()
          #crop_img_4 = crop_img_4.permute(2,0,1).float()


          crop_img_5 = torch.Tensor(prep(img[(img_row-h)//2:(img_row - (img_row-h)//2), (img_col-w)//2:(img_col - (img_col-w)//2)])).float().cuda()
          #crop_img_5 = crop_img_5.permute(2,0,1).float()


          stacked_tensor[pntr:pntr+5,:,:,:] = (torch.stack([crop_img_1,crop_img_2,crop_img_3,crop_img_4,crop_img_5]))
          pntr += 5 

          if annos[i,2] == 2: # 2 means it is test data
            test_labels.append(annos[i,1])

          else:
            train_labels.append(annos[i,1])

          '''
          mean_out_vggs = (stacked_tensor[0,:] + stacked_tensor[1,:] + stacked_tensor[2,:] + stacked_tensor[3,:] + stacked_tensor[4,:])/5

          if annos[i,2] == 2: # 2 means it is test data
            test_labels.append(annos[i,1])
            test_data.append(mean_out_vggs)

          else:
            train_labels.append(annos[i,1])
            train_data.append(mean_out_vggs)
          '''
          #print("image %d done"%(count))
          #count+=1
        #stacked_tensor = torch.Tensor(stacked_tensor)
        stacked_tensor_out = model(stacked_tensor)

        for j in range(0,batch_size,5):
          mean_out_vggs = (stacked_tensor_out[j,:] + stacked_tensor_out[j+1,:] + stacked_tensor_out[j+2,:] + stacked_tensor_out[j+3,:] + stacked_tensor_out[j+4,:])/5

          if annos[i,2] == 2: # 2 means it is test data
            test_data.append(mean_out_vggs)

          else:
            train_data.append(mean_out_vggs)         

    return([train_data,train_labels,test_data,test_labels])

# %%
import torchvision.models as models

vgg16 = models.vgg16(pretrained=True)
vgg16.classifier = nn.Sequential(*list(vgg16.classifier.children())[:-6])
[train_data_set,train_label_set,test_data_set,test_label_set] = load_dataset(vgg16)
# Out:
# In folder %s
#  ./images/v_000001  at time:  2019-11-22 10:28:20.782643
#
# In folder %s
#  ./images/v_000021  at time:  2019-11-22 10:30:44.100761
#
# In folder %s
#  ./images/v_000041  at time:  2019-11-22 10:33:39.637369
#
# In folder %s
#  ./images/v_000061  at time:  2019-11-22 10:36:58.322371
#
# In folder %s
#  ./images/v_000081  at time:  2019-11-22 10:40:26.366408
#
# In folder %s
#  ./images/v_000101  at time:  2019-11-22 10:43:55.327236
#
# In folder %s
#  ./images/v_000121  at time:  2019-11-22 10:47:22.798022
#
# In folder %s
#  ./images/v_000141  at time:  2019-11-22 10:50:50.679376
#
# In folder %s
#  ./images/v_000161  at time:  2019-11-22 10:53:41.303933
#
# In folder %s
#  ./images/v_000181  at time:  2019-11-22 10:56:32.589021
#
# In folder %s
#  ./images/v_000201  at time:  2019-11-22 11:00:06.128317
#
# In folder %s
#  ./images/v_000221  at time:  2019-11-22 11:03:37.436804
#
# In folder %s
#  ./images/v_000241  at time:  2019-11-22 11:07:08.794713
#
# In folder %s
#  ./images/v_000261  at time:  2019-11-22 11:10:35.605146
#
# In folder %s
#  ./images/v_000281  at time:  2019-11-22 11:13:19.094217
#
# In folder %s
#  ./images/v_000301  at time:  2019-11-22 11:16:10.946048
#
# In folder %s
#  ./images/v_000321  at time:  2019-11-22 11:19:45.109167
#
# In folder %s
#  ./images/v_000341  at time:  2019-11-22 11:23:12.387331
#
# In folder %s
#  ./images/v_000361  at time:  2019-11-22 11:26:41.744069
#
# In folder %s
#  ./images/v_000381  at time:  2019-11-22 11:30:08.545951
#
# In folder %s
#  ./images/v_000401  at time:  2019-11-22 11:33:39.863102
#
# In folder %s
#  ./images/v_000421  at time:  2019-11-22 11:36:34.179251
#
# In folder %s
#  ./images/v_000441  at time:  2019-11-22 11:39:24.362464
#
# In folder %s
#  ./images/v_000461  at time:  2019-11-22 11:43:02.235882
#
# In folder %s
#  ./images/v_000481  at time:  2019-11-22 11:46:34.616025
#
# In folder %s
#  ./images/v_000501  at time:  2019-11-22 11:50:04.439859
#
# In folder %s
#  ./images/v_000521  at time:  2019-11-22 11:53:30.039163
#
# In folder %s
#  ./images/v_000541  at time:  2019-11-22 11:56:49.247794
#
# In folder %s
#  ./images/v_000561  at time:  2019-11-22 11:59:35.536341
#
# In folder %s
#  ./images/v_000581  at time:  2019-11-22 12:02:55.465867
#
# In folder %s
#  ./images/v_000601  at time:  2019-11-22 12:06:28.639458
#
# In folder %s
#  ./images/v_000621  at time:  2019-11-22 12:10:02.208181
#
# In folder %s
#  ./images/v_000641  at time:  2019-11-22 12:13:55.247509
#
# In folder %s
#  ./images/v_000661  at time:  2019-11-22 12:16:53.029585
#
# In folder %s
#  ./images/v_000681  at time:  2019-11-22 12:19:48.311419
#
# In folder %s
#  ./images/v_000701  at time:  2019-11-22 12:23:19.476412
#
# In folder %s
#  ./images/v_000721  at time:  2019-11-22 12:26:53.178822
#
# In folder %s
#  ./images/v_000741  at time:  2019-11-22 12:30:23.546885
#
# In folder %s
#  ./images/v_000761  at time:  2019-11-22 12:33:58.869208
#
# In folder %s
#  ./images/v_000781  at time:  2019-11-22 12:37:31.716609
#
# In folder %s
#  ./images/v_000801  at time:  2019-11-22 12:41:07.617549
#
# In folder %s
#  ./images/v_000821  at time:  2019-11-22 12:44:22.875430
#
# In folder %s
#  ./images/v_000841  at time:  2019-11-22 12:47:40.350528
#
# In folder %s
#  ./images/v_000861  at time:  2019-11-22 12:51:16.114586
#
# In folder %s
#  ./images/v_000881  at time:  2019-11-22 12:55:00.945351
#
# In folder %s
#  ./images/v_000901  at time:  2019-11-22 12:58:39.634825
#
# In folder %s
#  ./images/v_000921  at time:  2019-11-22 13:02:28.809865
#
# In folder %s
#  ./images/v_000941  at time:  2019-11-22 13:06:10.868811
#
# In folder %s
#  ./images/v_000961  at time:  2019-11-22 13:09:28.955569
#
# In folder %s
#  ./images/v_000981  at time:  2019-11-22 13:12:22.278727
#
# In folder %s
#  ./images/v_001001  at time:  2019-11-22 13:15:54.091841
#
# In folder %s
#  ./images/v_001021  at time:  2019-11-22 13:19:36.277800
#
# In folder %s
#  ./images/v_001041  at time:  2019-11-22 13:23:15.059931
#
# In folder %s
#  ./images/v_001061  at time:  2019-11-22 13:26:50.848940
#
# In folder %s
#  ./images/v_001081  at time:  2019-11-22 13:30:25.061129
#
# In folder %s
#  ./images/v_001101  at time:  2019-11-22 13:33:35.995415
#
# In folder %s
#  ./images/v_001121  at time:  2019-11-22 13:36:34.196103
#
# In folder %s
#  ./images/v_001141  at time:  2019-11-22 13:40:18.282165
#
# In folder %s
#  ./images/v_001161  at time:  2019-11-22 13:44:04.535415
#
# In folder %s
#  ./images/v_001181  at time:  2019-11-22 13:47:49.915865
#
# In folder %s
#  ./images/v_001201  at time:  2019-11-22 13:51:50.101951
#
# In folder %s
#  ./images/v_001221  at time:  2019-11-22 13:55:22.975146
#
# In folder %s
#  ./images/v_001241  at time:  2019-11-22 13:58:39.629303
#
# In folder %s
#  ./images/v_001261  at time:  2019-11-22 14:02:01.999865
#
# In folder %s
#  ./images/v_001281  at time:  2019-11-22 14:05:52.021143
#
# In folder %s
#  ./images/v_001301  at time:  2019-11-22 14:09:34.447934
#
# In folder %s
#  ./images/v_001321  at time:  2019-11-22 14:13:18.198364
#
# In folder %s
#  ./images/v_001341  at time:  2019-11-22 14:17:14.237325
#
# In folder %s
#  ./images/v_001361  at time:  2019-11-22 14:21:19.845138
#
# In folder %s
#  ./images/v_001381  at time:  2019-11-22 14:24:55.096084
#
# In folder %s
#  ./images/v_001401  at time:  2019-11-22 14:28:28.143058
#
# In folder %s
#  ./images/v_001421  at time:  2019-11-22 14:31:56.233444
#
# In folder %s
#  ./images/v_001441  at time:  2019-11-22 14:35:39.535538
#
# In folder %s
#  ./images/v_001461  at time:  2019-11-22 14:39:25.953726
#
# In folder %s
#  ./images/v_001481  at time:  2019-11-22 14:43:31.004162
#
# In folder %s
#  ./images/v_001501  at time:  2019-11-22 14:47:10.184560
#
# In folder %s
#  ./images/v_001521  at time:  2019-11-22 14:50:39.872509
#
# In folder %s
#  ./images/v_001541  at time:  2019-11-22 14:54:00.416128
#
# In folder %s
#  ./images/v_001561  at time:  2019-11-22 14:57:36.658894
#
# In folder %s
#  ./images/v_001581  at time:  2019-11-22 15:01:19.637905
#
# In folder %s
#  ./images/v_001601  at time:  2019-11-22 15:05:04.924011
#
# In folder %s
#  ./images/v_001621  at time:  2019-11-22 15:08:48.245090
#
# In folder %s
#  ./images/v_001641  at time:  2019-11-22 15:12:30.523941
#
# In folder %s
#  ./images/v_001661  at time:  2019-11-22 15:16:08.064153
#
# In folder %s
#  ./images/v_001681  at time:  2019-11-22 15:19:09.788327
#
# In folder %s
#  ./images/v_001701  at time:  2019-11-22 15:22:25.183111
#
# In folder %s
#  ./images/v_001721  at time:  2019-11-22 15:26:03.356659
#
# In folder %s
#  ./images/v_001741  at time:  2019-11-22 15:29:43.580182
#
# In folder %s
#  ./images/v_001761  at time:  2019-11-22 15:33:25.425338
#
# In folder %s
#  ./images/v_001781  at time:  2019-11-22 15:37:06.157079
#
# In folder %s
#  ./images/v_001801  at time:  2019-11-22 15:40:18.471035
#
# In folder %s
#  ./images/v_001821  at time:  2019-11-22 15:43:19.293180
#
# In folder %s
#  ./images/v_001841  at time:  2019-11-22 15:47:01.441725
#
# In folder %s
#  ./images/v_001861  at time:  2019-11-22 15:50:43.561972
#
# In folder %s
#  ./images/v_001881  at time:  2019-11-22 15:54:29.710509
#
# In folder %s
#  ./images/v_001901  at time:  2019-11-22 15:58:18.700018
#
# In folder %s
#  ./images/v_001921  at time:  2019-11-22 16:01:22.219827
#
# In folder %s
#  ./images/v_001941  at time:  2019-11-22 16:04:49.779248
#
# In folder %s
#  ./images/v_001961  at time:  2019-11-22 16:08:30.878296
#
# In folder %s
#  ./images/v_001981  at time:  2019-11-22 16:12:21.026415
#
# In folder %s
#  ./images/v_002001  at time:  2019-11-22 16:16:12.031163
#
# In folder %s
#  ./images/v_002021  at time:  2019-11-22 16:19:33.559088
#
# In folder %s
#  ./images/v_002041  at time:  2019-11-22 16:22:31.141251
#
# In folder %s
#  ./images/v_002061  at time:  2019-11-22 16:25:52.167775
#
# In folder %s
#  ./images/v_002081  at time:  2019-11-22 16:29:42.877275
#
# In folder %s
#  ./images/v_002101  at time:  2019-11-22 16:33:42.851025
#
# In folder %s
#  ./images/v_002121  at time:  2019-11-22 16:37:36.467821
#
# In folder %s
#  ./images/v_002141  at time:  2019-11-22 16:41:36.839371
#
# In folder %s
#  ./images/v_002161  at time:  2019-11-22 16:45:32.144517
#
# In folder %s
#  ./images/v_002181  at time:  2019-11-22 16:48:46.060123
#
# In folder %s
#  ./images/v_002201  at time:  2019-11-22 16:51:44.317818
#
# In folder %s
#  ./images/v_002221  at time:  2019-11-22 16:55:03.630185
#
# In folder %s
#  ./images/v_002241  at time:  2019-11-22 16:58:55.213006
#
# In folder %s
#  ./images/v_002261  at time:  2019-11-22 17:02:49.262291
#
# In folder %s
#  ./images/v_002281  at time:  2019-11-22 17:06:41.871930
#
# In folder %s
#  ./images/v_002301  at time:  2019-11-22 17:10:34.852954
#
# In folder %s
#  ./images/v_002321  at time:  2019-11-22 17:14:34.438036
#
# In folder %s
#  ./images/v_002341  at time:  2019-11-22 17:18:00.618235
#
# In folder %s
#  ./images/v_002361  at time:  2019-11-22 17:21:02.288572
#
# In folder %s
#  ./images/v_002381  at time:  2019-11-22 17:24:38.603767
#
# In folder %s
#  ./images/v_002401  at time:  2019-11-22 17:28:32.614146
#
# In folder %s
#  ./images/v_002421  at time:  2019-11-22 17:32:30.004468
#
# In folder %s
#  ./images/v_002441  at time:  2019-11-22 17:36:19.149760
#
# In folder %s
#  ./images/v_002461  at time:  2019-11-22 17:40:00.855721
#
# In folder %s
#  ./images/v_002481  at time:  2019-11-22 17:43:06.430736
#
# In folder %s
#  ./images/v_002501  at time:  2019-11-22 17:46:29.391445
#
# In folder %s
#  ./images/v_002521  at time:  2019-11-22 17:50:21.835174
#
# In folder %s
#  ./images/v_002541  at time:  2019-11-22 17:54:47.357825
#
# In folder %s
#  ./images/v_002561  at time:  2019-11-22 17:58:38.918353
#
# In folder %s
#  ./images/v_002581  at time:  2019-11-22 18:01:49.916736
#
# In folder %s
#  ./images/v_002601  at time:  2019-11-22 18:04:53.134169
#
# In folder %s
#  ./images/v_002621  at time:  2019-11-22 18:08:57.968166
#
# In folder %s
#  ./images/v_002641  at time:  2019-11-22 18:12:53.763822
#
# In folder %s
#  ./images/v_002661  at time:  2019-11-22 18:16:48.287160
#
# In folder %s
#  ./images/v_002681  at time:  2019-11-22 18:20:39.884725
#
# In folder %s
#  ./images/v_002701  at time:  2019-11-22 18:24:16.375862
#
# In folder %s
#  ./images/v_002721  at time:  2019-11-22 18:27:12.099606
#
# In folder %s
#  ./images/v_002741  at time:  2019-11-22 18:30:54.620475
#
# In folder %s
#  ./images/v_002761  at time:  2019-11-22 18:34:46.378300
#
# In folder %s
#  ./images/v_002781  at time:  2019-11-22 18:38:32.529126
#
# In folder %s
#  ./images/v_002801  at time:  2019-11-22 18:42:28.236878
#
# In folder %s
#  ./images/v_002821  at time:  2019-11-22 18:45:41.397056
#
# In folder %s
#  ./images/v_002841  at time:  2019-11-22 18:48:35.238870
#
# In folder %s
#  ./images/v_002861  at time:  2019-11-22 18:52:12.899407
#
# In folder %s
#  ./images/v_002881  at time:  2019-11-22 18:55:57.510185
#
# In folder %s
#  ./images/v_002901  at time:  2019-11-22 18:59:45.436255
#
# In folder %s
#  ./images/v_002921  at time:  2019-11-22 19:03:34.020177
#
# In folder %s
#  ./images/v_002941  at time:  2019-11-22 19:07:22.478692
#
# In folder %s
#  ./images/v_002961  at time:  2019-11-22 19:10:42.931221
#
# In folder %s
#  ./images/v_002981  at time:  2019-11-22 19:13:57.836220
#
# In folder %s
#  ./images/v_003001  at time:  2019-11-22 19:17:47.186299
#
# In folder %s
#  ./images/v_003021  at time:  2019-11-22 19:21:36.800142
#
# In folder %s
#  ./images/v_003041  at time:  2019-11-22 19:25:24.156958
#
# In folder %s
#  ./images/v_003061  at time:  2019-11-22 19:29:17.850911
#
# In folder %s
#  ./images/v_003081  at time:  2019-11-22 19:33:40.057014
#
# In folder %s
#  ./images/v_003101  at time:  2019-11-22 19:37:00.146692
#
# In folder %s
#  ./images/v_003121  at time:  2019-11-22 19:40:11.881751
#
# In folder %s
#  ./images/v_003141  at time:  2019-11-22 19:43:33.636723
#
# In folder %s
#  ./images/v_003161  at time:  2019-11-22 19:47:20.979820
#
# In folder %s
#  ./images/v_003181  at time:  2019-11-22 19:51:20.092384
#
# In folder %s
#  ./images/v_003201  at time:  2019-11-22 19:55:08.096736
#
# In folder %s
#  ./images/v_003221  at time:  2019-11-22 19:58:57.702220
#
# In folder %s
#  ./images/v_003241  at time:  2019-11-22 20:02:49.255934
#
# In folder %s
#  ./images/v_003261  at time:  2019-11-22 20:06:17.454790
#
# In folder %s
#  ./images/v_003281  at time:  2019-11-22 20:09:39.159456
#
# In folder %s
#  ./images/v_003301  at time:  2019-11-22 20:13:21.452922
#
# In folder %s
#  ./images/v_003321  at time:  2019-11-22 20:17:02.702811
#
# In folder %s
#  ./images/v_003341  at time:  2019-11-22 20:20:40.586028
#
# In folder %s
#  ./images/v_003361  at time:  2019-11-22 20:24:19.310239

# %%
'''
import pickle
file = open("./train_data.pkl",'wb')
pickle.dump(train_data_set,file)
file.close()
file = open("./train_label.pkl",'wb')
pickle.dump(train_label_set,file)
file.close()
file = open("./test_data.pkl",'wb')
pickle.dump(test_data_set,file)
file.close()
file = open("./test_label.pkl",'wb')
pickle.dump(test_label_set,file)
file.close()
'''

# %%
import pickle
file=open('./train_data.pkl', 'rb')
train_data = pickle.load(file)
file.close()

file=open('./train_label.pkl', 'rb')
train_label = pickle.load(file)
file.close()

# %%
import pickle
file=open('./test_data.pkl', 'rb')
test_data = pickle.load(file)
file.close()

file=open('./test_label.pkl', 'rb')
test_label = pickle.load(file)
file.close()

# %%
############## training data processing from pickle data ###############

train_data_np = np.zeros(shape=[60225,4096])

for i in range(len(train_data)):
  train_data_np[i,:]  = torch.Tensor.cpu(train_data[i])

train_data_np_batch = np.zeros(shape=[60225//25,25,4096])

pntr = 0
for i in range(60225//25):
  train_data_np_batch[i,:,:]  = train_data_np[pntr:pntr+25,:]
  pntr += 25


train_label_np = np.array(train_label)

train_label_np_batch = np.zeros(shape=[60225//25,25])

pntr = 0
for i in range(60225//25):
  train_label_np_batch[i,:]  = train_label_np[pntr:pntr+25]
  pntr += 25


X,y = shuffle(train_data_np_batch,train_label_np_batch)

# %%
############## testing data processing from pickle data ###############

test_data_np = np.zeros(shape=[len(test_data),4096])

for i in range(len(test_data)):
  test_data_np[i,:]  = torch.Tensor.cpu(test_data[i])

test_data_np_batch = np.zeros(shape=[len(test_data)//25,25,4096])

pntr = 0
for i in range(len(test_data)//25):
  test_data_np_batch[i,:,:]  = test_data_np[pntr:pntr+25,:]
  pntr += 25

test_label_np = np.array(test_label)

test_label_np_batch = np.zeros(shape=[len(test_data)//25,25])

pntr = 0
for i in range(len(test_data)//25):
  test_label_np_batch[i,:]  = test_label_np[pntr:pntr+25]
  pntr += 25

# %%
del train_data
del test_data
del train_label
del test_label
del train_data_np
del test_data_np
del train_label_np
del test_label_np

# %% [markdown]
# ***
# ***
# ## **Problem 2.** Modelling

# %% [markdown]
# * ##### **Print the size of your training and test data**

# %%
# Don't hardcode the shape of train and test data
print('Shape of training data is :', np.shape(X))
print('Shape of test/validation data is :', np.shape(test_data_np_batch))
# Out:
# Shape of training data is : (2409, 25, 4096)
# Shape of test/validation data is : (952, 25, 4096)

# %%
# \*write your codes for modelling using the extracted feature (You can use multiple cells, this is just a place holder)

# %%
###################### LSTM class ####################

class LSTM(nn.Module):

    def __init__(self, input_dim, hidden_dim, batch_size, output_dim=1,
                    num_layers=2):
        super(LSTM, self).__init__()
        self.input_dim = input_dim
        self.hidden_dim = hidden_dim
        self.batch_size = batch_size
        self.num_layers = num_layers

        # Define the LSTM layer
        self.lstm = nn.LSTM(self.input_dim, self.hidden_dim, self.num_layers)

        # Define the output layer
        self.linear = nn.Linear(self.hidden_dim, output_dim)

    def init_hidden(self):
        # This is what we'll initialise our hidden state as
        return (torch.zeros(self.num_layers, self.batch_size, self.hidden_dim),
                torch.zeros(self.num_layers, self.batch_size, self.hidden_dim))

    def forward(self, input):
        # Forward pass through LSTM layer
        # shape of lstm_out: [input_size, batch_size, hidden_dim]
        # shape of self.hidden: (a, b), where a and b both 
        # have shape (num_layers, batch_size, hidden_dim).
        lstm_out, self.hidden = self.lstm(input.view(len(input), self.batch_size, -1))
        
        # Only take the output from the final timetep
        # Can pass on the entirety of lstm_out to the next layer if it is a seq2seq prediction
        y_pred = self.linear(lstm_out[-1].view(self.batch_size, -1))
        return y_pred.view(-1)

model = LSTM(4096, 200, batch_size=1, output_dim=25, num_layers = 1)

# %%
################### Training #####################

criterion = nn.CrossEntropyLoss()
lr = 0.01
optimizer = optim.SGD(model.parameters(), lr)

start_time = time.time()

max_epoch = 10
model = model.cuda()

for epoch in range(max_epoch):
      torch.cuda.empty_cache()
      total, correct = 0, 0
      for i in range(len(X)):
          model.zero_grad()

          imgs = torch.Tensor(X[i,:,:]).float().cuda()
          labels = torch.Tensor([y[i,0]-1]).long().cuda()
          #imgs = torch.Tensor(X[i,:,:]).float()
          #labels = torch.Tensor(y[i,0:1] - 1).long()
        
          model.hidden = model.init_hidden()
          
          outputs = model(imgs)
          outputs = outputs[None,:]

          #print(outputs.shape)
          #print(labels.shape)
          loss = criterion(outputs, labels)
          
          optimizer.zero_grad()

          loss.backward()
          optimizer.step()

          _, predicted = torch.max(outputs.data, 1)

          total += labels.size(0)
          correct += (predicted == labels).sum().item()
          
      print("Epoch %d done"%(epoch), end=' || ')
      print('Loss in this epoch: %f'%(loss.item()))
      accuracy_training = (correct/total)

print("\nTraining Done...\n")
print("Time consumption for training in seconds : %s seconds"%(time.time()-start_time))
# Out:
# Epoch 0 done || Loss in this epoch: 0.074263
# Epoch 1 done || Loss in this epoch: 0.062681
# Epoch 2 done || Loss in this epoch: 0.023163
# Epoch 3 done || Loss in this epoch: 0.011352
# Epoch 4 done || Loss in this epoch: 0.005188
# Epoch 5 done || Loss in this epoch: 0.005598
# Epoch 6 done || Loss in this epoch: 0.004407
# Epoch 7 done || Loss in this epoch: 0.003889
# Epoch 8 done || Loss in this epoch: 0.003494
# Epoch 9 done || Loss in this epoch: 0.003200
#
# Training Done...
#
# Time consumption for training in seconds : 129.76984429359436 seconds

# %% [markdown]
# ---
# ---
# ## **Problem 3.** Evaluation

# %%
# \*write your codes for evaluation (You can use multiple cells, this is just a place holder)

# %%
criterion = nn.CrossEntropyLoss()
lr = 0.01
optimizer = optim.SGD(model.parameters(), lr)

start_time = time.time()

max_epoch = 5
model = model.cuda()

total = 0
correct = 0
with torch.no_grad():
      for i in range(len(test_label_np_batch)):

          imgs = torch.Tensor(test_data_np_batch[i,:,:]).float().cuda()
          labels = torch.Tensor([test_label_np_batch[i,0]-1]).long().cuda()

          outputs = model(imgs)
          outputs = outputs[None,:]


          _, predicted = torch.max(outputs.data, 1)
          #print('predicted = ',predicted)
          #print('actual = ',y[i,0])
          
          #print('for i = ',i)
          total += labels.size(0)
          correct += (predicted == labels).sum().item()
          accuracy_testing = correct/total
      

print("\nTesting Done...\n")
print("Time consumption for training in seconds : %s seconds"%(time.time()-start_time))
print('Testing Accuracy for epoch %d: %f'%((epoch + 1), (accuracy_testing) * 100))
# Out:
# Testing Done...
#
# Time consumption for training in seconds : 2.120577335357666 seconds
# Testing Accuracy for epoch 10: 79.936975

# %%
################### SVM MODEL #####################

from sklearn.svm import LinearSVC
from sklearn.metrics import accuracy_score

clf = LinearSVC(C=0.0001, random_state = 1)

train_data_svm = np.reshape(X,(np.shape(X)[0],np.shape(X)[1]*np.shape(X)[2]))
train_label_svm = np.max(y,axis= 1)

test_X = np.reshape(test_data_np_batch,(np.shape(test_data_np_batch)[0],np.shape(test_data_np_batch)[1]*np.shape(test_data_np_batch)[2]))
test_Y = np.max(test_label_np_batch,axis= 1)

start_time =time.time()
clf.fit(train_data_svm, train_label_svm)
print("Time consumption for training: %s seconds" %(time.time()-start_time))

prediction_train =clf.predict(train_data_svm)
accuracy_train_svm = accuracy_score(prediction_train, train_label_svm)


start_time = time.time()
prediction_test =clf.predict(test_X)
print("Time consumption for testing: %s seconds" %(time.time()-start_time))

accuracy_test_svm = accuracy_score(prediction_test, test_Y)

print("Accuracy: ",accuracy_test_svm*100)
# Out:
# Time consumption for training: 522.8843989372253 seconds
# Time consumption for testing: 0.27826905250549316 seconds
# Accuracy:  83.40336134453781

# %% [markdown]
# * ##### **Print the train and test accuracy of your model**

# %%
# Don't hardcode the train and test accuracy
print('Training accuracy is %2.3f' %(accuracy_training*100.00) )
print('Test accuracy is %2.3f' %(accuracy_testing*100.00) )
# Out:
# Training accuracy is 100.000
# Test accuracy is 79.937

# %% [markdown]
# * ##### **Print the train and test and test accuracy of SVM**

# %%
# Don't hardcode the train and test accuracy
print('Training accuracy is %2.3f' %(accuracy_train_svm*100.00) )
print('Test accuracy is %2.3f' %(accuracy_test_svm*100.00) )
# Out:
# Training accuracy is 100.000
# Test accuracy is 83.403

# %% [markdown]
# ## **Problem 4.** Report

# %% [markdown]
# ## **Bonus**

# %% [markdown]
# * ##### **Print the size of your training and test data**

# %%
# Don't hardcode the shape of train and test data
print('Shape of training data is :', )
print('Shape of test/validation data is :', )

# %% [markdown]
# * ##### **Modelling and evaluation**

# %%
#Write your code for modelling and evaluation

# %% [markdown]
# ## Submission
# ---
# **Runnable source code in ipynb file and a pdf report are required**.
#
# The report should be of 3 to 4 pages describing what you have done and learned in this homework and report performance of your model. If you have tried multiple methods, please compare your results. If you are using any external code, please cite it in your report. Note that this homework is designed to help you explore and get familiar with the techniques. The final grading will be largely based on your prediction accuracy and the different methods you tried (different architectures and parameters).
#
# Please indicate clearly in your report what model you have tried, what techniques you applied to improve the performance and report their accuracies. The report should be concise and include the highlights of your efforts.
# The naming convention for report is **Surname_Givenname_SBUID_report*.pdf**
#
# When submitting your .zip file through blackboard, please
# -- name your .zip file as **Surname_Givenname_SBUID_hw*.zip**.
#
# This zip file should include:
# ```
# Surname_Givenname_SBUID_hw*
#         |---Surname_Givenname_SBUID_hw*.ipynb
#         |---Surname_Givenname_SBUID_hw*.pdf
#         |---Surname_Givenname_SBUID_report*.pdf
# ```
#
# For instance, student Michael Jordan should submit a zip file named "Jordan_Michael_111134567_hw5.zip" for homework5 in this structure:
# ```
# Jordan_Michael_111134567_hw5
#         |---Jordan_Michael_111134567_hw5.ipynb
#         |---Jordan_Michael_111134567_hw5.pdf
#         |---Jordan_Michael_111134567_report*.pdf
# ```
#
# The **Surname_Givenname_SBUID_hw*.pdf** should include a **google shared link**. To generate the **google shared link**, first create a folder named **Surname_Givenname_SBUID_hw*** in your Google Drive with your Stony Brook account.
#
# Then right click this folder, click ***Get shareable link***, in the People textfield, enter two TA's emails: ***bo.cao.1@stonybrook.edu*** and ***sayontan.ghosh@stonybrook.edu***. Make sure that TAs who have the link **can edit**, ***not just*** **can view**, and also **uncheck** the **Notify people** box.
#
# Colab has a good feature of version control, you should take advantage of this to save your work properly. However, the timestamp of the submission made in blackboard is the only one that we consider for grading. To be more specific, we will only grade the version of your code right before the timestamp of the submission made in blackboard.
#
# You are encouraged to post and answer questions on Piazza. Based on the amount of email that we have received in past years, there might be dealys in replying to personal emails. Please ask questions on Piazza and send emails only for personal issues.
#
# Be aware that your code will undergo plagiarism check both vertically and horizontally. Please do your own work.
